# %%
import pandas as pd
import numpy as np
import nltk
import re
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM, Conv1D, MaxPool1D, BatchNormalization
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix



#We are going to use word vectorization to embed the words
import gensim

# %%
bot_tweets = pd.read_csv('processed_bot_tweets.csv')

# %%
human_tweets = pd.read_csv('processed_human_tweets.csv')

# %%
del bot_tweets['Unnamed: 0']

# %%
del human_tweets['Unnamed: 0']

# %%
bot_tweets['isBot'] = 1

# %%
human_tweets['isBot'] = 0

# %%
tweets = pd.concat([bot_tweets, human_tweets])

# %%
tweets.rename(mapper = {'0':'text'}, axis = 1, inplace = True)

# %%
tweets['text'] = tweets['text'].astype('str')

# %% [markdown]
# # Preprocessing the tweets
# Here, we shall do things like change common short hands into full form (in order to deal with the issue of punctuation removal)

# %%
#First, we convert words like can't, won't etc into cannot and will not
short_form_dict = {
"ain't": "is not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he'll've": "he he will have",
"he's": "he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how is",
"I'd": "I would",
"I'd've": "I would have",
"I'll": "I will",
"I'll've": "I will have",
"I'm": "I am",
"I've": "I have",
"i'd": "i would",
"i'd've": "i would have",
"i'll": "i will",
"i'll've": "i will have",
"i'm": "i am",
"i've": "i have",
"isn't": "is not",
"it'd": "it would",
"it'd've": "it would have",
"it'll": "it will",
"it'll've": "it will have",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she would",
"she'd've": "she would have",
"she'll": "she will",
"she'll've": "she will have",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so as",
"that'd": "that would",
"that'd've": "that would have",
"that's": "that is",
"there'd": "there would",
"there'd've": "there would have",
"there's": "there is",
"they'd": "they would",
"they'd've": "they would have",
"they'll": "they will",
"they'll've": "they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what'll've": "what will have",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"when's": "when is",
"when've": "when have",
"where'd": "where did",
"where's": "where is",
"where've": "where have",
"who'll": "who will",
"who'll've": "who will have",
"who's": "who is",
"who've": "who have",
"why's": "why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you would",
"you'd've": "you would have",
"you'll": "you will",
"you'll've": "you will have",
"you're": "you are",
"you've": "you have",}

# %%
tweets.head()
# Out:
#                         text  isBot
# 0      extract aveng scaveng      1
# 1               get geotherm      1
# 2  spell panopli without pli      1
# 3         put myrrh commerci      1
# 4       need die spell muddi      1

# %%
#Things to keep: Capitalisation of words, punctuation, emojis and their positions

# %%
#Preprocessing steps (ie cleaning of text and including important information like emojis)

# %% [markdown]
# # Train test split, model training and word embedding

# %%
#create the X and y classes
#tweets['isBot'] = 0
#tweets.loc[tweets['account_type'] == 'bot', 'isBot'] = 1
y = tweets.isBot
X = tweets[['text']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
#first, just embed the cleaned tweets and see the results

#store the cleaned tweets in a list of lists representing the split
X_train_sentence = [d.split() for d in X_train.text.tolist()]

# %%
X_train.text.tolist()
# Out:
# ['sweepstak monstertruckjumpl',
#  'stand hr stop social disguis infrastructur',
#  'hey watch ring power stream tonight birthday',
#  'bad move juve tie guy year make qualiti move',
#  'sure dopplegang mimic',
#  'job done cypru big credit tonight',
#  'twitterversari twitter year sinc sep via',
#  'miss',
#  'sorri miss chocol ring doughnut keep eye peel alway new tasti product launch',
#  'right amount phallic',
#  'feel home mont carlo',
#  'take break creat video recov sinu infect move later week settl new hous feel well start pump episod stay cozi beauti photo credit',
#  'super excit play lovevalleyfest year saturday main stage see ticket sale',
#  'know similarli afflict',
#  'sinc june low capr fare xbi spi capr mkt cap still paltri fulli fund p multi billion tam mileston payment partner high likelihood fda let compani file bla acceler approv come wk',
#  'octob mean hellrais love movi incorpor storylin blood gut gore write writingcommun horrormovi horror horrorfamili horrorart lgbtq',
#  'live chat elana myer taylor kind awesom',
#  'man sleep wan na go poundtown look like finna drive mile wake as like come let yo melatonin',
#  'told look like late teen earli probabl highlight life',
#  'love cocker coupl',
#  'everyon sd rn get invit',
#  'thank',
#  'swim lesson pilaf',
#  'hit account shut one',
#  'cruis ship cargo ship',
#  'wish man could see girl nice time play game bar gall go tell play differ',
#  'saturday look like day',
#  'wow thank much realli appreci',
#  'welcom lavend meghanmckeown break transfer florida impact could make terp',
#  'cri cri cri',
#  'window art wednesday post art walk around photograph art find hope see tomorrow kellylanemiddleschool windowartwednesday pfisdfineart',
#  'let understand scienc behind behavior chang habit make stick shapa',
#  'put motiv boil',
#  'your put new featur good use',
#  'salman sea stori seventh wave episod',
#  'shoe shine addawordruinahorrormovi',
#  'instrument tune weekend found play piec sinc late said let imagin everyth tune',
#  'guess doin somethin right',
#  'sure read garbag ww use lotion bath wtf think keep bbw busi last time wash hair thing differ repli racist af',
#  'insid head christoph storer co especi last two episod make anyon whose ever keep togeth repeatedli say fine put fryer fire feel le alon surviv chao thebear',
#  'pleas share u touch alex',
#  'huge thank team cover humbl bless get repres bad bone capco boy howboutdemcapcoboy issu',
#  'curiou fastest grow sector broadband industri learn fix wireless latest broadband video capitoconnect',
#  'day sigh miss',
#  'hey hey hey globalhandwashingday kaya bioderm beat germ viru proper handwash ever let spread word life saver stay safe ka tropa leveluphandwash',
#  'break swedish scientist svant paabo win nobel prize medicin',
#  'exactli get',
#  'decad taken brave posit biggest global issu fair trade gender equal climat justic turn need stand challeng orthodoxi around world respond need injustic',
#  'new p polic bring imag advic commun town hall woodlandhil fentanyl school age child',
#  'buy got beani mail btw thank good qualiti shiz buy',
#  'gunnersauru',
#  'get bonu track name well',
#  'decid draw selfi make video process made eye hurt eye hurt one favorit song garbolog project smartest peopl video',
#  'pleas keep u friend famili prayer come day prepar brave hurricaneian potenti aftermath damag destruct may caus floridastrong sarasota gulfcoast swfl flwx',
#  'ye look lol xxxx',
#  'thank',
#  'tempt troubl tale dirti wow check',
#  'final feel like found passion present host someth alway want full time given chanc thrive wait see journey take',
#  'octob monthli goal via',
#  'michigan though still get anyth like video lol',
#  'monday favorit sure sometim need fresh perspect move day nevergiveup mondaymotiv getoutofyourownway',
#  'need stiletto fri pan foostep type sound',
#  'mayb right tbt',
#  'ok give lisa rinna realli funni',
#  'solid competit silat practition bracket',
#  'facebook ig back fuck',
#  'grow',
#  'russianron bottom cap time editori viru infect wisconsin idea tie parti futur delusion huckster recommend fight covid listerin deepli unsettl',
#  'fridaynightbattlefield thank fun game',
#  'test let peopl check drug deadli fentanyl save life encourag abus state disagre',
#  'zoel hello year old cocker spaniel known majest white blond coat peer window brooklyn height good dog',
#  'back mainstag',
#  'happi birthday m stanley miss today kill mockingbird quit without',
#  'peopl unfollow automat check',
#  'search partner visit leav brandi woo fun time',
#  'late spent four day edinburgh last night york today drove north york moor nation park whitbi head back york via scarborough',
#  'wonder lil cherri think',
#  'babi boomer still amaz much privat inform user give away free fb sell anyon will pay one claim surpris use nefari purpos shock shock find gambl go',
#  'dez',
#  'oh ej knew exactli rinna go',
#  'seen yet littl busi ny comic con',
#  'thank glad know use exampl educ student hope speak think limit understand attempt occur legal financi intimid scientist need awar knowledg case fight back',
#  'bed room repli',
#  'dress rehears short audio reflect wake app',
#  'real estat invest alway easi invest paid like crazi check ten best real estat invest ever remax st servic maria casa cell mariacasa remax net',
#  'realiz today one realli defin noodl chicken noodl choos whatev noodl suit fanci',
#  'think lie age year stop turn midway year lie titl tuesday good though assum cheat tourney fals posit',
#  'bruhhh god left shower caus mini flood outsid rainyday saturdayvib nyc',
#  'hahaha start left leg usual rep slow',
#  'post photo',
#  'usual put trough slowli walk away lol',
#  'one week go love theballroomblitz next thursday pre order enter competit win panto ticket see book tour pre order competit book tour anton xx',
#  'fashion week approach took look thread last sever decad year favorit look',
#  'also felt like expend consider effort drag metaphor finish line year span subtl yet sizabl impact life seen almost year alreadi hurt expect miss',
#  'say side good v man rub aspect quicker play design get guy open man instead someon win could good set',
#  'mid day portofla bikesharechalleng go catalina express waterfront park west undefin undefin',
#  'insan gomarin',
#  'readi vampireacademi virtual premier thank amaz drink dinner wait stream first four episod tonight',
#  'enough enough georgian deserv leader integr like let make sure send back unit state senat second term',
#  'omg photo real lol look like photoshop lol yeah ronni look like someon took favorit toy away',
#  'renter guid prepar natur disast landlord leas usatoday hurricaneian renter',
#  'lot go earlier week still make way thru report finish watch make happi read dark read read think lot love proud',
#  'three best ever femal vocalist fabul person',
#  'thank respons make xd',
#  'invit come join u ballgam',
#  'win unit robert morri wright state line',
#  'best buy retail lock item fight theft though question cost',
#  'synth pop boy creat album good charlieputh',
#  'learn grammar child problem punctuat take time tonight help child',
#  'one person unfollow automat check',
#  'great medit lightwork intern holistichealth bestlif cheyenn mountain zoo',
#  'sebong con complet without proper memento get holo photo taken smart booth first floor moa arena betsinmanila bethesuninmnl smartviuwithseventeen',
#  'liter ugli pic look good lookin',
#  'septl day streak septl bonu',
#  'came hookah loung serv food friend look crazi walk back doordash',
#  'bar said bar saloon bar georg baker',
#  'love cookwar',
#  'blame appropri',
#  'omg congrat man happi guy beauti',
#  'proud daughter claudineljean natur black hampton air theblackhamptonsbet hampton bet betplu carlweb tridestinedstudio urbanbooksmedia tv limitedseri',
#  'thank much',
#  'receiv peer recognit photographi',
#  'public school student told go career fair actual brought christian event student divid gender girl listen talk rape forgiv offend boy told compet money push up wtf',
#  'thank great tip',
#  'damn rooster start cookooorooo minut alarm ima go find',
#  'husband play video game obnoxi peopl world',
#  'rise mine',
#  'alreadi tomorrow wasnt day',
#  'done acheron rick partlow',
#  'grab',
#  'seafood night',
#  'friend slay togeth stay togeth back manila week ig still itali livenowpostlat',
#  'break ukrain russia belaru right activist win nobel peac prize',
#  'bring back mexican pizza',
#  'excit hoodi night come perfect midweek adventur lfgsd',
#  'bet',
#  'sent one nicest place u find fault anyth',
#  'tinder swindler documentari netflix great watch unbeliev woman gullibl beyond naiv still claim love mf r end made mad',
#  'donald got bed pillow robe atlantafx',
#  'hug dw shana tova whole famili',
#  'note fortherecord',
#  'common type apart',
#  'congratul alghanim industri menatalentaward',
#  'awesom best cheerlead ever',
#  'join playunifi movement athlet includ respect',
#  'meenalagarw naren benedict anticast ankitmalik',
#  'look like siberian cat mayb',
#  'possibl fullpotenti liveoutloud liveonpurpos audac thinkbig thinkdiffer',
#  'eat bitch',
#  'click link take quick look call servic proactiv polic work done polic depart august pasadenagov',
#  'forget origin spiderman movi second better aaaaand go',
#  'treatyourself contest',
#  'nice oh ahh teach uh go fish',
#  'oh ghana road porthol depress difficult drive ghanaian roadway sinc move one porthol anoth porthol tough',
#  'mortgag lol',
#  'drink magnific beast',
#  'smile make u happier scienc say ye',
#  'cours man carri life within bodi tell woman bodi way stop pregnanc sex parti want babi',
#  'readi newest jai alai ipa mix pack varieti pack differ iter flagship beer includ brand new hazi jai alai ipa fan favorit spanish cedar jai alai ipa look near come week',
#  'command wish answer see color',
#  'lol miss good time brisha rest group memori cherish',
#  'group text say want announc dunno let day lot hockey histori thank entertain boy thankyoupk nhl nhlbruin gohabsgo',
#  'chao way',
#  'afford',
#  'rememb join twitter mytwitteranniversari',
#  'damn cook ru tl turn game nd qtr lmao',
#  'yet reason still watch',
#  'sri pat pete that dez bryant cowboy card',
#  'readi christma',
#  'awesom neat read love stori wp',
#  'christian courtship procedur',
#  'evlut thank follow check site',
#  'stay posit test neg play footbal',
#  'attent uk fan tonight mel brook night bbc four thur sept nd start pm mel brook unwrap imagin old pal alan yentob follow doubl featur produc blaze saddl',
#  'thank much encourag word support make one day time alonetogeth staystrong staysaf healthcarehero',
#  'born creativ system slap u artist',
#  'publish articl today say quit tour tell emot rollercoast today watch bobweir true deadandcotour deadandcompani',
#  'lfg tonight',
#  'cours best know difficult',
#  'thank god day',
#  'noth say dont join live mirrativ',
#  'got funni feel read write wall',
#  'life short sittin round miser peopl gon talk whether doin bad good true',
#  'mayb great music great hip hop',
#  'current commit other could put loss se libra',
#  'hell miss golden gem tweet hope well dood',
#  'week hell popcorn machin went rampag new jersey philodendron wield machet mushroom play synthes chipotl test new tortilla chip ai',
#  'readi come',
#  'took two strong irishman crowbar pri bundl fluff arm',
#  'ima tell jewish ppl',
#  'seoul happi got visit new place',
#  'next gener theragun pro help maintain consist warm recoveri year next gener smarter quieter ever keepmov',
#  'civil leap forward',
#  'rock hour pm cst come rock',
#  'xfccaabcfecacaa curiou nft world want give shot see happen go',
#  'love love love guy biggest heart funnest job yet watch show without happi tear',
#  'stay safe fin',
#  'let see end',
#  'guess buy new car know noth car',
#  'tbt photo bowi bowieforev',
#  'took chico state volleybal game much fun chicost volleybal gowildcat california state univers chico',
#  'rememb join twitter mytwitteranniversari',
#  'citat need ronjohnsonserveshimself gopli truthmatt',
#  'polic sheriff wrong gang extort harrass go around steal money peopl never met plant drug car harrass child barbosa fulton co sheriff',
#  'race witch mountain light year earth ufologist conspiraci theorist vivisect',
#  'trade adopt pleas',
#  'never dog way better cat',
#  'dow drop point nasdaq close lower rate pop septemb job report cnbc',
#  'redeem team doc good even know stori intens invest start finish kobe bean guy diffrent speci altogeth theredeemteam blackmamba',
#  'happi becca hope find true love find funni name bachelorett sure mend broken heart hope tia go next bachelorett fun funni brighten show afterthefinalros',
#  'terribl round come bomb along bushey martin wat onto morden merton bestcouncil car obsess even bang tart central reserv urban dual carriageway',
#  'guess support citizen educ camp',
#  'easi answer afraid dark',
#  'ye garret white call great white come baltimor baltimorefitnessexpo',
#  'fund opportun museum iml grant program accept applic nov find',
#  'abigi outwest plaidshirt magnificentseven inspir shoot dalla texa',
#  'excit share detail ml platform infra work reddit realli begin',
#  'thank keisha',
#  'mayor eric adam declar state emerg migrant crisi say nyc track spend billion',
#  'way put blast',
#  'secureourfutur town hall meet miami art studio zelda glazer deliv key statist mileston reach continu invest safeti secur',
#  'omg ye know one favorit tv show gag time',
#  'someth weekend pr',
#  'hey happi birthday month',
#  'tonight dinner thank crescent humuhumu dinner grandwailea maui catchthecurr rick gunderson humuhumunukunukuapua',
#  'author figur could throw wrench pla virgo',
#  'friend anyon interest go look raporipcrawl',
#  'wish patricia interest sky beantown late',
#  'morn chop tweepz ref',
#  'petal search app petal search enjoy everi moment life',
#  'huge news one better job congrat friend',
#  'peopl act like refer someon prefer pronoun problem call grown man bubba ho',
#  'anyon els count day',
#  'haiti ask world militari help curb chao',
#  'influenc jake zyru cover explicit via',
#  'today latinx law cuban american',
#  'got correct end season',
#  'chipotl judg away',
#  'enjoy work yao adversari exampl passion teach would make great advisor anyon consid grad school deep learn right',
#  'throwback cover icantgoforthat',
#  'think run supervisor comment came sit slocounti supervisor week board supervisor meet slocosup sloco h',
#  'better two co worker share septemb birthday seven co worker share birthday celebr septemb birthday quarterli meet last week join u send birthday wish heidi patrick rachel b rachel r maggi kathi alexi',
#  'everi week uk lose peopl suicid take lost hour walk octob help chang howev choos walk rais vital cash help support life save servic unitedagainstsuicid',
#  'definit wear',
#  'counter person court addict determin control state control state state school polit state',
#  'experi worldwid sensat moonag daydream cinema visit ticket bowiemoonagedaydreamfilm',
#  'drake door thank pin kany',
#  'conveni go lead anyth good',
#  'get holiday spirit',
#  'travesti',
#  'wish dear friend twitter happi navratri may durga visit hous ten day shower bless jai durga',
#  'problem tri reschedul',
#  'ye vote gfi',
#  'xo x shm live desert avail hr',
#  'one rise star pretti good think lead italian adac f championship season',
#  'stream trial tribul mixtap via',
#  'yesterday rd best open q spx sinc tabl show perform balanc q top along subsequ perform interst also spx risen q line top',
#  'setup shot',
#  'ye clair inde',
#  'someth va deni pain medic forc take suboxon approv fda pain',
#  'one person follow automat check',
#  'time done retir couch televis remot hand screen still concept sit around watch movi lot appeal action least distract',
#  'well said brother bravooo',
#  'flip side tho multiversu realli fun give time work season pa',
#  'season scrub want someth special call friend brought u new ioniq sent u drive watch premier episod hear full episod podcast thank hyundai ad hyundai ioniq',
#  'break man charg alleg kidnap sexual assault incid excelsior spring',
#  'sweet post bunion surgeri action thank genet alway futur youuuuuuth point shoe definit exacerb issu genet primari factor also pl excus lean mom cours snap pic balanc',
#  'yike billboard chosen fake vandal one cring worthi attempt market seen long time',
#  'son desper disabl get med hospit could get ppl give would help u get halfway goal could retain lawyer pleas help donat share',
#  'hello octob theme octob event swag go octobercelebr sunriseprint mondayvib',
#  'heart north sydney busi district offic miller street place surround profession advertis market financ collabor come easi wework cowork space sydney schedul visit today',
#  'footbal time',
#  'disco inflect song welcom return best make swoon danceabl pop inflam romant within',
#  'damn good day get one two paint mail talent wait hang',
#  'offer accommod costa rica medic tourism paradiseoutlook',
#  'success',
#  'whatsapp connect data use whatsapp studi',
#  'translat stop normal everyday american start look act like empti suit snake oil salesman like fake dr oz',
#  'tfw gender swap give male option app see girl',
#  'saw former student store morn specif thank show write essay th grade said use whole life weep desk morn stop happytear',
#  'tri help homeless peopl bring person care servic hair food shower etc place need tri get truck run abl deliv free hot meal need pleas consid donat spread awar',
#  'thank share',
#  'fall underway pay get home prepar upcom weather',
#  'curiou well',
#  'excit',
#  'among european bank see nd largest increas short sell past day want know watch video sdata hedgefund sentiment creditsuiss',
#  'nearli made',
#  'eat one wild mushroom risotto fritter sundri tomato jam saltwatercat irvin losangel foodporn cater luxuri california foodgasm foodblogg igfood tasti lovefood goodeat eeat oceat tableset chef',
#  'thank',
#  'alway lab',
#  'tonight make bodi scrub luxuri trust know famili better vibrat planet',
#  'christma come earli come bear gift thrill share trailer new film fall christma netflix novemb th song sound familiar',
#  'know probabl old news saw today make mom heart burst',
#  'sweet tooth went away stop smoke',
#  'beyonc congratul sister solang becom first african american woman compos new york citi ballet might suggest f si',
#  'new car final back stock buyer might abl afford',
#  'good morn',
#  'see miss love',
#  'one person unfollow automat check',
#  'famili valu gop forgav josh duggar molest child forgav roy moor relentless sex predat forgiv herschel walker domest abus absente father lie mani kid pay abort lie',
#  'writer elig ppp loan see possibl',
#  'let mf trick think u gangster trap type shxt whoever tf u genuni accept round ya peer get cha circumfer asap',
#  'ahead time',
#  'hey fan club hous think nd favorit pa announc let go cat flpanther vamosgato',
#  'proud',
#  'mr champak state mind love insid make sure show outsid angrezimedium stream kareenakapoorkhan deepakdobriy dineshvijan homiadajania dimplekapadia',
#  'serious sonja kind idiot',
#  'destroy peopl pull clip spot whenev tri doubl talk whatev',
#  'extrem excit share stage friend pepsihalftim show introduc next saga career bigger better ever nbcsport sblvi',
#  'next week join high energi famili friendli show bring music vibe johnson nativ new orlean atrium saturday free entri first come first serv david rubenstein atrium',
#  'left alon year old day old mother abus',
#  'take look insid underground network gamer bring obscur japanes arcad titl statesid via',
#  'fear small mud want taken care peopl',
#  'exactli continu stay humbl humil gift wisdom everybodi let peopl talk alway reveal true natur bless',
#  'good thing',
#  'journalist interview jeffrey dahmer psychopath via',
#  'glitch nodej color gener bot error codeart cosin origin img pq',
#  'definit school year tough',
#  'brewer start play hour padr tomorrow',
#  'gold e k wooyoung need self esteem boost taecyeon fault wooyoung taecyeon past wooyoung wooyoung',
#  'fallout end blew mind broke heart',
#  'without trust faith without faith imposs pleas god read coach revtrev negativityfast posit livelight coach jesu god bibl revtrev negativityfast posit',
#  'latest live fit daili thank fit tech',
#  'data diod v unidirect gateway ransomwar chang market connect without risk latest podcast episod special guest rare treat listen',
#  'bless thursday',
#  'thank done u go way back time ohio statehous npr good luck next adventur',
#  'wtf wrong peopl encourag peopl save energi energi climat crisi woke lot realis wast time energi switch phone',
#  'one person follow automat check',
#  'unreal got month back b',
#  'pl deaf one ear',
#  'attitud made say never play golf trump cost',
#  'wheel time panel new york comic con teas massiv scale season includ arriv ceara coveney elayn',
#  'wish way order see one arriv first abl return loser',
#  'grant u stop ask k',
#  'former critic think say takedown get better make day',
#  'work relat activ sinc forgot felt like day left wide open still feel like actual hope chang soon get actual stuff',
#  'much fun game havingablast trashpanda',
#  'cri cri thank roger class grace show sport nadal far greatest sport hero girl could fedalforev',
#  'start phase two refrigeratorwar branch redactedwar wont believ follow tiktok ig hint day',
#  'whitehelmet',
#  'dust settl pirat becom rich found mystic school',
#  'ghana nation theater accra design cheng tain gift china softpow architectur',
#  'anyon make life even littl bit easier bless',
#  'blurri photo bush panther alert',
#  'got someth special come way',
#  'need nois lootbox strike electrifi fenc',
#  'thank puerto rico count usacitinzen fionapr weneedy',
#  'appreci partnership mission',
#  'dog watch entir week get cute',
#  'littl squeal shimmi',
#  'coog suffer first loss footbal tonight volcano vista keep head boy guy still one best record state guy respect young men campu keep work hard guy go coog',
#  'download animalcrossingpocketcamp year lord partak franchis first time life',
#  'guess diogo jota readi make comeback brace weekend back sidelin becom inevit spur penalti v u',
#  'thank time famili thank increas job market save life pre exist condit mandat obamacar cours grace god may thanksgiv thank god bless',
#  'ridicul servic ever never deliv date call hear bullshit mouth im sick tire servic order deliv would chang heart beat',
#  'holi quran certainli satan lead astray excit vain desir bid slit ear cattl bid alter allah creation aye proceed schedul god',
#  'achiev chor',
#  'gon na impress',
#  'enter winter veil giveaway via gleam win sylvana statu mount pet prize click link enter whveilgiveaway',
#  'listen talk colin wright mindboggl bravo',
#  'would bring back heart beat come sign autograph track would stop charg much mayb one day',
#  'pupsi today hot even hotter bio ha ha ha',
#  'go whine got mash potato french fri realli want time step plate belli bar time look fate squar eye flare nostril breath life last breath',
#  'omg white rabbit tomorrow night confirm sick hope stay awak smackdown',
#  'wear mask indoor one month travel week sinc arriv philippin alway best mask covidisnotov',
#  'men hold share stock necess provid anxieti tranquil boredom amus',
#  'ye rhode island grandmoth even small dog name sweet pea',
#  'tri draw first',
#  'ya know mean way anyth right',
#  'hear dildo newfoundland canada nice time year right kinda windi tho could check nearbi concept bay virgin cove tickl harbour blow come chanc name town newfoundland',
#  'bambi',
#  'hardli think complain state fact languag fundament crucial part speech',
#  'horribl take context realli occur high end onlin game solv',
#  'time',
#  'poet marc olmst review new biographi gonzo journalist hunter thompson written beatdom magazin editor david will',
#  'pray dat god might bring ppl da right thing spike lee hope ppl stick togeth like siames',
#  'ever sinc came team made big differ glad senior great leader guy speedi recoveri see next season',
#  'go work danc mode',
#  'may bridg burn light way',
#  'view tonight front porch',
#  'shop mattel barbi dia de lo muerto doll day dead collector box new truegeth',
#  'energi sector big frothi head toward weekend',
#  'proper nutrit follow puberti blocker hormon appropri either assign birth gender transit gender go appropri puberti develop healthi adult risk muscl bone loss pale compar suicid',
#  'must shed grey matter clown clear',
#  'gay remain undef',
#  'amen yep',
#  'good morn peanut festiv morn ahead special day parent preschool age child listen great deal today detail',
#  'mine back check suspend spam today',
#  'long charact continu drink straight room temperatur gin count',
#  'yeah poitrin half big consid',
#  'often accident type beset somehow feel right anyway',
#  'one lifetim goal becom profession astrolog want formal educ abl help other knowledg',
#  'scene taught never cheat black woman singl finger forehead push say babi slap',
#  'limit mani time game set',
#  'sweatshirt cart time press check gone hella heartbroken xoxox',
#  'winter may come new ferrari',
#  'absolut let go met',
#  'love everi minut rip cabinet paint away yellow green',
#  'ivot turn txt vote visit vote locat selfi',
#  'lol tweet got fool narc',
#  'asham handl lose labwork order outreach customerservic peopl wait import result go make busi make brush rug wonder mani lost',
#  'bro scream',
#  'bless drop album road deliver',
#  'still favorit set moment commerci shoot mom wife asian fam watch tv home white costum design ask white director shoe want u wear director ask u actor would wear say wear shoe shoot shoe',
#  'track pad tortur pleas give extern mous',
#  'bottom right pic though',
#  'land free',
#  'stream live bit',
#  'snapchat privat photo famili use someon cia identifi photo',
#  'get better man finna spazz like ppl last hr',
#  'class session dreamseat coloradounivers school colleg classisinsess',
#  'good tell becom friend someon never meet close friend met red flag',
#  'also watch right',
#  'peac love nowar',
#  'cuz beauti smart woman hand scammer full shitter ask logic question poor whittl brain handl melt dumb fawk need realiz tht woman stupid desper',
#  'hope ok worri boutcha',
#  'oh gosh oh gosh go ed cours want happiest end ed need stede need hear got back day scotland refus go bed caught ta gift stori',
#  'appli today busi analyst fort lauderdal fl job',
#  'hear lost championship micki jame contract impact week wonder whether gon na come back wwe tripl h charg creativ one peopl',
#  'one person follow automat check',
#  'know much stupid take wors told u bigli trump win reelect',
#  'ya im perform issu dx mostli dx better still stutter dx fine yesterday patch fukd',
#  'first time appli reject',
#  'true effect ausdrecken',
#  'design canva minut pump get',
#  'fair question rush acquir tast zz top hitmak two differ audienc',
#  'either crash big go',
#  'serious want deal peopl anymor today dont like way angri make feel',
#  'hell go downtimesuck',
#  'child god creation long reveal read scripturethatsperson coach revtrev negativityfast posit livelight coach jesu god bibl revtrev negativityfast posit',
#  'back rock new highground keyboard',
#  'rubbish mmr matchmak system trash',
#  'hi kenya power power acc happen frequent pleas help fix',
#  'thank spend minut year wrap',
#  'big time red flag peopl never dap properli',
#  'iheartmindi realsaavedra guy special fakenew lockerroomtalk oh biden biden biden trumpi shame bootlick veryfinepeopl',
#  'price rent import sacramento fewer resid make enough money buy home current price ff',
#  'thank much ted realli appreci get daniel howev get hope enjoy',
#  'think differ emphasi discoveri valid timebox limit assumpt hypothesi gener lean canva work team empti brain discoveri beginn mind',
#  'great news see knife pack crowd one favorit theatric experi time',
#  'fallen one myth email market join tuesday find click regist bryan cohen free event',
#  'femal fe iron male man therefor iron man hahahaah xd k',
#  'fact',
#  'lyn thank fantast team much great night full hous nicest crowd could ever wish meet',
#  'noth dope',
#  'progress drum bass bb fb ebd bfa aef',
#  'shout awesom custom servic total recommend shoppurpl',
#  'alway indoor cat later year figur old make happi',
#  'chanc app numer flaw get fix anytim soon would wonder possibl sooooo mani upset peopl would happi made function properli pleas help u merci',
#  'bottom red small sampl size wonder drive narr larger one show broader pattern mean c mon stat like year sampl size hard extrapol year period stronger',
#  'ever put togeth outfit realiz complet trash end day walk around look like complet moron hour worst feel ever get home look mirror pretti much fall apart ttlo',
#  'pittsburgh weather overcast dark damp make want curl ball sleep miser weather make miser day hate day like feel like twilight damn day',
#  'bo come bang fantast portray class version mass present kudo team success godfath',
#  'give letemknow',
#  'seen univers written beth kimmi rhode beth new album crazytown watch whole video jeremi ryan get crazytown bethnielsenchapman crazytown theunivers',
#  'statement nebraska gov rickett say choos pursu senat appoint succeed sass leav next governor definit',
#  'think rinna crop nd pic bet hand kyle shoulder hahaha freakin love rhobh',
#  'brand new lift last day simpli good enough getiffix poorservic notgreat',
#  'tonight criticalrol begin hour return jrusar bell hell seek aid desper bid save friend travel histor local join u',
#  'album mixtap busi droppin album mixtap build busi contact u daili promo',
#  'peopl follow one person unfollow automat check',
#  'driver use blinker mind reader',
#  'twitter deal high stake poker game daniel ive',
#  'jokr still favorit callofduti warzon warzoneclip topcodplay',
#  'thank u brother best memori',
#  'love girl much',
#  'specif biden open border sinc trump oh wait noth go ahead tri find law even procedur actual chang love see link show border open',
#  'rest trust provis',
#  'would done everyth attend hollywoodwalkoffam ceremoni sad la day person favorit singer lost count mani time seen live definit go watch livestream',
#  'watch neighbor use garden hose help hfd battl kaneoh hous fire hnn',
#  'big truck',
#  'mean like mail check card go get abort',
#  'virtu signal woke ideolog climat zealot shriek phoni scienc sme oap societi vulner life risk anoth wef exercis societ control next thing aka gov psyop polar drive mass obedi',
#  'morgan x inch morgancar',
#  'absolut love tng happier agenc home profession alway u truli feel like famili best cast opportun represent la vega hand thank tng tngmodelsdowork',
#  'excit beyond measur next season also know ship wreck',
#  'lane frequenc brooklynhairstylist hairstylist newyorkhairstylist stylist queenshairstylist bkhairstylist nyhairstylist tattoo tattoo',
#  'websit rt like see myprowebsit itsthateasi',
#  'nan',
#  'talk mean know serious',
#  'woke sore throat time play least favorit game show allergi cold covid strep',
#  'ricki thank much kind word realli appreci',
#  'pryor ok born rais music festiv',
#  'april umpir ted barrett spoke tini microphon said review call confirm suddenli one basebal remot figur becam bit human',
#  'brand new possibl crossov show',
#  'kona silver ironman world championship great britain luci charl barclay claim silver first woman race',
#  'tour date octob charlott nc even muse ticket show click link',
#  'hi work vfx studio would like connect freelanc opportun involv ai interest could dm open dm',
#  'wuv wuv',
#  'wtf cancel bad move countri huge disservic end inform program realli go miss sunday morn bring back reliablesourc',
#  'gm thought bless pictur real one rememb episod cheadl guest star golden girl snapplefact',
#  'master puppet omfg im die',
#  'respect obgyn would tell call embryo eighth week pregnanc gong forward call fetu born',
#  'lmao day ddo attack simp want bullshit handl blizzard everyon know enough server support mani peopl tri play mainli game die last year blizzard go keep server',
#  'brother teammat fight disagr alway stay hous video smh',
#  'trump slave also want putin slave cult weird',
#  'queen shat someon bed undignifi',
#  'metamorphosi anoth engag excit lesson educ fund food forest eddi edfundgarden lakestevenselementari lake steven elementari',
#  'hypothes type person never delet old email also never use sell useless inventori video game thought gameovergreggi',
#  'thank award math grant appreci',
#  'funni see struggl defend candid keep sweat hand honestli write gce privat candid sure recent though funni look face got laugh',
#  'td yard liter better first half mahaom yeah total bench',
#  'ugh even food',
#  'morningvib bunpavmaska hot cuttingchai mumbaistyl',
#  'land god monster',
#  'met fan marri padr fan realli sure prepar weekend cc',
#  'watch two girl tonight knowledg passion level next level one reason get stay late well worth',
#  'audac',
#  'singl yong bu arriv least time allow u enjoy citi streetscap topoli',
#  'like captur memori share preciou moment love one forget histori countri came djiholiday enter dji festiv calendar chanc win dji mysteri futur box join via',
#  'assum also onejack twojack show',
#  'absolut amaz love',
#  'come tonight',
#  'aunti lg belanja biskuit buat babi vasha gita sara fresh fruit store pic',
#  'life one desper wish meet one time hero idol',
#  'amaz stop busy awhil concentr import thing life faith famili bless normal take grant daili quarantinelif devot embrac',
#  'ghost mr chicken love',
#  'velvet rodeo take journey earli music today see tonight vega',
#  'florida man arrest kidnap girlfriend year old boy led offic chase use child human shield outsid mcdonald last week author said',
#  'louder back',
#  'whatev updat occur son lost myplay nba kand hard contact custom support',
#  'hey seen lol',
#  'better intend good dog',
#  'sold last week min last night sold min believ live art',
#  'say prayer good say prayer bad',
#  'left seem anyth kill black peopl abort obes gangviol',
#  'fascin multipl way show good ai task rel cluster human champ comparison cascad import choic game',
#  'wish daughter back school time',
#  'guilt live allentown pa',
#  'sourc tell tmj wisconsin badger fire head footbal coach paul chryst detail news',
#  'pandem yet trainer yell fresshhhh cut georg haircut gave',
#  'name one america best workplac year tri award year team sauc proud honor among prestigi list compani across countri incbestworkplac',
#  'fill go error box top noth highlight tell wrong',
#  'maria echeverria esri confer scienc',
#  'ima stick besid mayb go red tabl talk',
#  'cast tiana princess frog tell disagre',
#  'newprofilep',
#  'pleas friend carol suffer heart attack might need surgeri thank',
#  'life beneath snow unsulli wild delic done war',
#  'make sure watch huluweendragstravaganza',
#  'song got feel first heard zan w lean',
#  'everyon go sad summer fest year im jealou hope fun',
#  'hope see real soon info',
#  'therefor urg irish govern immedi announc support extend june wto decis trip agreement therapeut diagnost test without restrict condit',
#  'would sort delight accident wander possum turf absolut kick as',
#  'man',
#  'found transpond snail giant sea monster amaz encount trecru',
#  'appar trumpchristmasshutdown potu use air forc one person trip',
#  'much lost pay ppp loan politician busi',
#  'believ accident wear glow dark nail color hahaha know last night',
#  'got kid',
#  'take pic without glass bc liter never put back',
#  'seriou sugar high happen grade offic right courtesi mr mr thank',
#  'hello',
#  'pray mom kurt lost mother alzheim three year ago miss dearli stay strong brother',
#  'hous horrif rhoslc',
#  'oh yeah forgot thing',
#  'alyssa thompson st cap yo england k fan typic day year old thatsthetea',
#  'cdcsay ye fli jump roof believ hard enough',
#  'three year lifetim go',
#  'est low key spin',
#  'alga black hole',
#  'greyblu green grass soft blue',
#  'heehe salamat thelinyalinyashow kilig na th episod ako love',
#  'mysteri dismiss happen often enough stori categori',
#  'pleas peopl call show u diehard special teamer',
#  'nux pedalboard giveaway win allinon direct directsolut worship worshippedalbaord minipedalboard dualped',
#  'fourth straight win shutout number year eagl blank averett road bleedcrimson goforgold',
#  'hola tiempo sin hablar ig whatsapp fb',
#  'cal poli receiv million california institut regen medicin regen medicin seek develop sort medic treatment drug stem cell devic help peopl regener part bodi learn',
#  'someth didnt want u southernaftlif',
#  'custom servic far underwhelm unprofession assur would issu fund howev sever issu top someon respond dm ask email disappear provid',
#  'enjoy happi new year',
#  'everbear peach paint mari daisi arnold',
#  'friend interest go look borregohilaria',
#  'evid support assert',
#  'happi ladi',
#  'experi excit monmouthu get glimps offer student join u annual fall undergradu open hous sunday octob learn',
#  'fact father shadow god earth sweet father may live long healthi wealthi life',
#  'damian lewi trade floor chariti cure eb sir hvh art foundat bgc chariti day view photo get detail damianlewi cureeb hvhart bgccharityday bgcchariti bgccharityday',
#  'know never got twitter figur good time ever use see everyon promot here hope gather follow work courag stream mayb ill even post youtub depend everyth',
#  'womenwithfilm womenmgmt',
#  'girl liter woke cri littl went work',
#  'mean realli though hit head give spear lol def best ahhhhh hahaha',
#  'time tomorrow tailgat athen pre game war eagl tiger beat godawg',
#  'gogo power ranger go go power ranger',
#  'age everyth declin includ muscl bodi overal amount muscl bodi tie rate metabol everybodi age gender need incorpor resist train fit exercis workout gym getfit shape',
#  'break sr engin tell undercov journalist twitter believ free speech confess employe tech giant commi f k admit left wing employe hate capitalist takeov attempt twitterexpos',
#  'exampl someon transpar crowd fund lawsuit',
#  'congratul',
#  'way chop hair',
#  'compar risk mortal deploy afghanistan hour period friday constitu meet also think move math former would higher lot would high',
#  'denver hous tour backyard reveal',
#  'ye ugh love much',
#  'great job',
#  'back fact give back season blacktanktop bookclub',
#  'happi chip billion whatev need one mate text elon musk find friend musk text messag reveal power appetit tech bro musk set twitter',
#  'new releas earli monkeypox data unvax ppl x like get infect got st dose dose jynneo vaccin cdc also expand elig vax ppl might risk futur',
#  'better get good pee wind',
#  'quick tip sustain digit lend progress video',
#  'help reach follow halfway way',
#  'share new crescent moon star expand charm ring adjust silver charm dangl ring ladybugfeet jewelri design start shop',
#  'ye move administr process th chang issu th today wait deliveri took approxim week date drop box appoint',
#  'stand impact snuggl welli',
#  'weird pre clean vacuum floor set roomba like asham would judg first run',
#  'mani rail employe requir work hour day frequent call hour day seven day week rail worker say often make leav request month advanc',
#  'account hack chang secur question russian abl chang password pleas help',
#  'donat differ life graduat avid senior',
#  'visit',
#  'noth fact peyton safe',
#  'sleep mac eat',
#  'famili smfh',
#  'yo babi gon na dri placenta grind powder put capsul tell friend drug enlighten yo know pick duck',
#  'commun inform abstract rule infer philosophi logic philosophi',
#  'itali want get restaur recommend see sight florenc bologna montalcino montepulciano tuscan countrysid follow instagram post anyth twitter',
#  'anyon propos panel pleas feel free put potenti speaker research social medium misinform onlin health scienc comm ethic macro micro level medium effect also first gen disabl',
#  'suck bad person harm countless peopl bullshit delet account',
#  'starlight space cadet process',
#  'final rememb word look theyr like colon sim dont wan na colon pl e e',
#  'europ doubl cycl post covid recoveri plan',
#  'law corrupt core weapon law enforc agenc credibl peopl countri',
#  'rip wonder cat live nearli yr joy',
#  'sincer grate one cast resplend winner audi award book year kelli gildea brilliant director',
#  'glenco al go vote ivot electionday',
#  'went hometown detroit see put amaz show hometown detroit special',
#  'flight classic come next thursday oct got awesom trailer',
#  'unfortun chase never allow thing pursuit happi sad',
#  'nevada mail vote step closer becom perman',
#  'join experi thrill fifa world cuptm contact offici hospit packag fifawordcup qatar officialhospit officalhospit matchhospit fanaticsport collab',
#  'today th day libra day scorpio',
#  'dark mode easier navig page remov websit facelift thank user feedback work ensur easi use access ever think',
#  'think go win v',
#  'recruit cloth llc develop integr commun exploit call jawbon startup',
#  'oh p chick wave makin heart shape w hand blowin kiss thru tour bu door window wave back forth wish coulda got pic wichu sadli miss chanc till next time suppos xoxoxox',
#  'alreadi laugh joke like bring tabl',
#  'thread got valuabl content ever seen twitter',
#  'octob mental ill awar week year theme wish known focus power live experi learn nation allianc mental health websit',
#  'wonder crowd tunbridg well thank come ace support podcast mug well done flower podcast thank donat',
#  'true ur troll',
#  'would mad ask retroact estim cost law includ futur polici chang new law facilit mean say obamacar law creat icr program allow pay repay instead like end',
#  'hate peopl make differ choic simpli believ someth grate choic make first place',
#  'georgestrait lot common',
#  'man happier thank entergalact',
#  'one person follow automat check',
#  'thank',
#  'sure andrew made life stress hope chase charl like bat outta hell',
#  'good catch w beauti niec',
#  'capcom alongsid member x forc',
#  'explain kid freedom usa men especi like gun second amend reign suprem understand fixthecountri',
#  'even know say honest',
#  'realli put l game day',
#  'two inspir person singl frame',
#  'tri high fall wine chardonnay red blend rose avail tap',
#  'check friend around great guy new book block financi road map year block life hot new releas amazon grab copi',
#  'hahaha killa know get done none happen lol damn killa',
#  'dayton v wakeforest bad game',
#  'forget gift card use zell learn',
#  'hey',
#  'happi caturday miss sangha new bookcas nap spot blackcatsofinstagram blackcatsrul bedstuycat blackcatsruletheworld writerscat catswhoread',
#  'lesson learn bounc back alway',
#  'dead end long corridor old photo confus lynx skeleton',
#  'get leather',
#  'good victori road break go',
#  'thank much',
#  'realli sit plane minut get u new one wast time vacat nothappi',
#  'support tri get card unlock week app chat email readi leav curv complet feel messag get ignor',
#  'last night special way rememb special person forev',
#  'come dwt',
#  'thank see sunday',
#  'right',
#  'take min empti dishwash would rather flue',
#  'love littl heart spidey know movi deadpool much love vanessa loveee show screen romanc spidey deadpool uwwwwu',
#  'got kick public librari noth',
#  'seven way social medium shape beauti industri',
#  'disgrac commun side peopl hate exist shame',
#  'doggo chill back',
#  'post photo pari franc',
#  'actualtech medium hand meet glad see orlando still well hope',
#  'mr marri person',
#  'untru friend boo',
#  'natur essenti everyon covid via',
#  'thank',
#  'ocean twp',
#  'thread',
#  'playstat team crisi text line struggl mental health crisi text line counselor avail anyon live u free text circl info visit',
#  'flower new websit ad directori',
#  'probabl nose stuffi hate',
#  'beauti talent joy induc sound choreographi thank share gift public may return multipl found feed thank spread joy',
#  'good share check item love poshmark fashion style shopmycloset dooneybourk etienneaign southernlivingathom',
#  'hey idea friend pleas step outsid take breath come back',
#  'beauti also special look delici save seat',
#  'pre order print book oh suppos tell pre order version book get listen earli chapter audiobook enter receipt',
#  'emoji frank lloyd wright',
#  'tri price number',
#  'miami good',
#  'seen none true unless anoth',
#  'want complet disconnect workahol persona say ye take meet vacay bc great opportun disconnect right promis',
#  'shit actual fire',
#  'thigh meant danc',
#  'horribl custom servic chat peopl call time open ticket help would never recommend',
#  'updat new io right credit reserv respect owner follow tech',
#  'keith would go tribal',
#  'think yesterday follow k peopl post video also photo well captur',
#  'great way end nationalcoachesday togeth coach rockchalk readi',
#  'hawk eye soni',
#  'realiz mosquito bite human definit guid ankl biter mosquito',
#  'reform defundthepolic',
#  'thank sorri delay respons move onlin hope enjoy',
#  'danc chicken smh',
#  'game',
#  'stabl bore',
#  'discountwork fantast way work home make money onlin find cheap worker help busi',
#  'posit',
#  'yeah that one violat couch everi night',
#  'stringent overreach code propos would imperil america abil deploy clean energi fight climat chang clean energi compani sign seia letter call voter reject',
#  'holi shit',
#  'newprofilep',
#  'right back ya fun night xx',
#  'would watch voic actor scoobi doo show movi ok',
#  'spread took precaut test',
#  'tel mathay shobai tel dey mean',
#  'thank belov chiranjeevi garu grace occas inaugur allu studio arg',
#  'seen record break number amazon fire deforest septemb broke new record amazon deforest devast biodivers local commun global climat savetheamazon',
#  'young turk live break biden warn nuclear armageddon foxnew trot climat denial trump latest reveng plot click link forget join convers use tytliv show',
#  'eat ice cream work five hour',
#  'take pledg fire cracker diwali give smile unknown face pledg r donat myfmindia arvindkejriw cpcb offici anandmahindra mrmotilalosw pmoindia nischay nomoreshor spreadsmilesthisdiwali',
#  'happi sunday zooey yellow dog dog cutedog aussiesofinstagram bordercolli sunday sundayfunday happi weekend autumn weekendvib',
#  'year fli fast',
#  'imagin rob murder someon get lock wk later u end person life never outsid enjoy stole gon na drop knowledg youth scare straight year ttlo',
#  'go reshar sinc back news',
#  'love site',
#  'process server go weekend holiday et ye halloween work go get pillowcas candi neighbor dress still call email today servic start tomorrow',
#  'protect phish attempt stop receiv suspici messag email think click link attach look clue sender number email messag phrase tone messag cybersecmonth',
#  'bird feather flock togeth iron pigeon strong pigeonhol',
#  'us word scum anymor',
#  'expect',
#  'notic trump becom better presid stay mr trump',
#  'peopl follow automat check',
#  'court recess',
#  'prepar singl mom',
#  'ye mani time book week advanc even one turn test',
#  'cooler weather come keep fashion warm granni hexagon cardigan sweater handmad sweater etsi cbu germanvillag shoploc etsyfind crochetlov handmad crochetlov grannysquar columbusohio farmersmarket',
#  'let known fact mom suggest bike ride',
#  'found transpond snail battl rage upper yard shandian v kami trecru',
#  'secretlab new chair',
#  'post photo lo angel california',
#  'park commun advoc park see tomorrow',
#  'mean pretti great',
#  'conquer stress overthink guid peac happi mental health seri book mind power tool also worst enemi let take control life',
#  'hello mel beat also pleas damon kelli fincham universityofgalway ie',
#  'besid overs jedi sith holocron',
#  'bitch dick nigga run',
#  'boom lfgsd capturethemo',
#  'first game season belter v live pm doyl exet mayb',
#  'found transpond snail candid shot straw hat new ship merri trecru',
#  'first night back work time roll',
#  'note okay stop',
#  'fave',
#  'someon put brown banana break room today',
#  'teanu unlock phone face id',
#  'forgot outrag',
#  'ambassador mari yovanovitch sue guiliani defam lockuprudi',
#  'adapt die adapt die realli complic understand might time reassess move thought',
#  'morn got bacon nom mommi bobbi go littl visit michigan accept treat reliev mommi guilt',
#  'beauti day',
#  'hottest ever liter ever downsid lean dunham entir thing main love interest',
#  'stat day arriv new unfollow stat via',
#  'peopl follow automat check',
#  'cryptocurr poker connect find answer articl blog check cryptocurr blockchain poker',
#  'jasonwucollect',
#  'lack pet snuggl cat allow',
#  'good move happi birthday janic',
#  'could stop put ukrain togeth russia beloru context',
#  'gig log photo danc parti',
#  'thank',
#  'realli hate tell mom safe church',
#  'pat patriot uniform back weekend rememb threw td includ nd quarter via detvsn sunday pm et fox stream nfl',
#  'littl known fact musician mani metal band actual werewolf go long way toward explain hair',
#  'adjust dumbbel clone good',
#  'fun match alway love tag girl',
#  'enjoy hell premier andor tonight refresh see starwar firmli go new direct explor new world cultur stori kyle stoller gave seriou twinpeak agent cooper vibe wonder consult',
#  'experienc yoke owner x still prefer wheel loaner howev buy aftermarket wheel want test see much obstruct screen truli prefer problem none option offer return polici',
#  'wednesday vip nfl unit run today rc run today tgtbfc octob run',
#  'today son alex hike entir loop trail ten fall silver fall nation park walk k total includ initi k wrong path simpli beauti',
#  'wow udc realli number',
#  'follow unfollow know simpl get weekli stat via',
#  'sustain campu index uc merc place top sever categori includ tie spot research annual report recogn top perform colleg univers sustain impact area',
#  'sick bodi sick craft industri',
#  'good morn toni',
#  'rayban onlin sunglass special price one day',
#  'glad hear appreci sought provid voter comprehens debat',
#  'today everi day proud incred talent visionari bo congrat write shabbi either',
#  'read heard guess godmoth stepmoth habit say everi game',
#  'gop main goal tax cut wealthi deregul wealthi want particular industri matter cost u middl class matter cost environ',
#  'newprofilep',
#  'belief run u could anyth obviou',
#  'sir sorri troubl insignific issu maharaja club member last month email messag call call centr request reset password ffp account action pleas help',
#  'et p pt john yoo williamjbennett dave sear robertpatillo aswoy lucasfoxnew mattfinnfnc ashleystrohmi pdooci jengriffinfnc foymeetsworld',
#  'fair stupid word',
#  'cori bush amazon shut work climat disast plan via',
#  'hey mr dj put record fridayfunday guineapig',
#  'somewhat surpris link real madrid',
#  'clearli watch mine mom pass dad glass let go',
#  'turn channel everi time come air realli interest opinion wonder regular segment think go watch',
#  'sweet harper rose jumpsuit maci super comfi afford fave two thing thank watch',
#  'crucial thing understand even especi u whose paycheck rel sizabl take home month ever liter pay bill miss even one paycheck work poor vote like',
#  'playground la noth account competit pleas delet account twitter alreadi notifi thank',
#  'go research anyth mudrickcapit sell boycot mess ape boycottmudrickcapit need show busi mess u ape',
#  'hey go fuck',
#  'could nomin lot non meteorologist',
#  'pm pst apr th great time get sale team page salesenabl wfh',
#  'bisexu best famili',
#  'zach feldman talk thot hxt new song whatev',
#  'clever',
#  'morn ran across articl digg made curou pull stat one gener high traffic site',
#  'yum sound good',
#  'tennesseest tsu homecomingweek wait see day octoberth tbt ticket',
#  'go bear ucberkeley bidenadministr',
#  'see someon drive lamborghini first thought must taken big student loan went colleg curiou',
#  'lol shit two day ago',
#  'lot inspir first evil dead',
#  'miscellan meander may',
#  'love pictur',
#  'miralteas wish bro team huge success axessfilm',
#  'want apolog bit weather thank covid tri keep cough line love thank fan rock rio everyth fuck great crowd',
#  'heat',
#  'dress like champion new mike tyson essenti drop live',
#  'produc monoprint stencil due wed mar',
#  'look like sever messag record sent salford show reappear form',
#  'care one core valu one reason proud work client like everi day organ like nijc make differ learn help effort visit websit',
#  'kid away school month brought home weekend entir sure go let go',
#  'rd gen appl tv app store',
#  'brand',
#  'definit correct cut congressut',
#  'think matt perhap possibl',
#  'histor context bond crash rd great bond bear market thu far doozi global govt bond loss cours wors sinc marshal plan credit anstalt treati versail cc',
#  'stream hour play follow',
#  'bet brave lol',
#  'readi give point',
#  'wooow bellissimo grazi bayernbarca',
#  'best site web internet archiv non profit librari million free book movi softwar music websit',
#  'well escal quickli',
#  'arriv brasseri princ lunch discov kitchen close sunday must money make day especi hungri diner wait fabul food',
#  'differ year make love uncl littl girl',
#  'pleas urgent get back hour sinc respons visa appoint work day away pleas help',
#  'chat journey entrepreneurship',
#  'polic say year old lauren mari dooley perform oral sex date bind wrist ankl duct tape bizarr order doordash',
#  'includ mini case studi new author brand prog strategi help creat one loyal loyal fan base world bt armi stori amaz daughter armi consult',
#  'promis',
#  'born flyer fan futur flyer start',
#  'trump say kid still ice find parent well taken care one danger heartless aw lie ever said',
#  'love moment like',
#  'chanc appli interview place holyhead sixth form come see u gcse result day pm pm',
#  'everi day new product start st day week good expect',
#  'fragranc wardrob gift pride encapsul entir legend ensembl discoveri box apt gift special one enchant begin legend madeinindia diwali',
#  'muslim woman real feminist',
#  'followfriday top influenc week great weekend tri',
#  'happi friday kick weekend make sure peopl getvotereadi mid term elect import sit let nationalvotereducationweek',
#  'got paid mother trucker worn blue jean sinc like march found dollar pocket morn feel like champion champion dollar',
#  'go austin work five day start sunday miss last time let make mistak happen',
#  'member would like word ask correct retract articl',
#  'love footbal love rosicki arsen wenger',
#  'thank water bottl lol',
#  'explos robert discov anna doubl agent could destroy robert left career shatter suffer great injuri anna persev pregnant robin knew surviv child gh',
#  'far possibl without surrend good term person czetli',
#  'someth break',
#  'get w glad back ravin bleedblu gododg dodger la chavezravin dodgersfamili dodger stadium',
#  'ye',
#  'fort myer oct climat high low precip snow miss',
#  'least peopl kill iran okay call galvan world support woman freedom enddominationofwomen',
#  'guess fast plane trip boston minneapoli instantan',
#  'happen panhandl tri extort money peopl non stop rob peopl via cashapp aggress panhandl bear respons fix',
#  'gin shinsen center roku gin passion fruit mint lemon way warrior sake right',
#  'dysonschool alway give bigredprid',
#  'hi sorri phone must think call spam call pleas send email number call back thank',
#  'worst counti elect staff job honor get call email threaten violenc call traitor deplor behavior',
#  'never quit clear theolog underpin post millenni',
#  'journo line kindergarten teacher think deserv higher',
#  'may rest peac',
#  'ha love shane btw beef anyon certainli respect everyon contribut poor mike although new follow hilari pm nice silver line',
#  'came back minut later',
#  'needl say go long road wife forgiv whatev happen deserv wake fuck bud',
#  'loyal fan love special go home go home peac',
#  'best luck',
#  'post photo alethia tanner park',
#  'adult longer powerless littl one immens love tender forc need moment trauma ask amanda trauma survivor ask kid',
#  'excit join bro tour wait see beauti peopl ticket pre sale octob th',
#  'hight level panel futur wine tourism alla gcwt modera winetour',
#  'handov manag infrastructur commun support group team expert clean water flow week plead court allow deliv servic',
#  'matchday fulham premierleagu matchday',
#  'one person unfollow automat check',
#  'whoa tmobiletuesday go big year thankiversari awesom deal free stuff month check getthank',
#  'work first person nft project talent annabella nardini insta annabelladraw updat come soon',
#  'discountwork fantast way work home earn money onlin find cheap worker help busi',
#  'u understand pain lmao',
#  'sick entertain peopl like idea hold vision old version longer reflect treat peopl way fair time came reflect upon',
#  'truli genuin authent allow vulner authent genuin vulner',
#  'sadden learn sudden death godfath young age inspir love read write also univers professor',
#  'success mind power action',
#  'congrat win world seri',
#  'tigertal mavsntig pic clemson student',
#  'okay ye talk alreadi',
#  'time actual happi see naeher',
#  'wempl captur well enough',
#  'peopl unfollow automat check',
#  'tsunami went',
#  'omg first person kill lol weird flex',
#  'excit book song ahh go amaz',
#  'kate yeah whatev handcuff snap onto wrist s nearli',
#  'one best impuls decis',
#  'press play',
#  'nah caus best time ever last night concert love interact crowd good vibe best concert sure',
#  'nowher rather friday night address citi ward chair group go help u bring home pa day',
#  'coffe kind morn shellacmanicur romantiqu freshmanicur naturallook',
#  'local bookstor awesom got keeper lowel',
#  'post photo',
#  'appar twitter hack sinc afk apolog spam retweet',
#  'event celebr hispan heritag month',
#  'get kobe morn need',
#  'hi love connect chat sext dick rate video call right subscrib account sign',
#  'great thank much sent dm',
#  'know rasheeda hurt whatev babi cri tear later get hoe as kirk as tf lhhatl',
#  'never felt prettier get old men let vaccin',
#  'write book abund lost vision make realiti build work suppli side progressiv abund go fun',
#  'pablo free mint live',
#  'mayb one day alumnu stuff wmsc',
#  'new eminem snoop dogg track drop hour ago',
#  'came say',
#  'pack crown royal care packag support troop want share generos join mission purplebagproject',
#  'sure issu would emerg manag em pandem expert top els ph offic lead coordin need messag em offic seem em relat issu cdc fema commun well',
#  'dad defi odd walk journey grace digniti ed love famili shown help sustain still',
#  'ye buy game deliv tomorrow howev free keychain arriv today separ up pouch thank',
#  'nashvil tenn ap offici vanderbilt univers medic center announc friday paus gender affirm surgeri minor order review practic',
#  'watch episod tuesday night chat phone make differ therenov',
#  'ah zee empti life zee dog must watch felin get play fetch ala mousi thrown',
#  'use xbox gamepass cloud game steam deck brilliant steamdeck xboxgamepass',
#  'fcc lift transpar requir internet provid isp',
#  'dat judi weigh lb oughta get tax credit lol thang heavi toddler',
#  'thank tri u everyon x',
#  'earn crisp day level badg',
#  'forgiv student debt everi student parent ever paid back student loan agre claim entir refund irrespons thing buy vote',
#  'proud flatter ask part werewolfbynight first flame tuba public imag big show year month day later',
#  'thank recent follow happi connect great thursday tri',
#  'rip gangsta paradis moment life rap song violin disney legend',
#  'speech head state joint sit parliament',
#  'profil stackabl pad height mm spacer fit whatev pole want pad amaz noth without aftermarket alway bolt someth differ',
#  'countri dose tea origin collect english tea got even tin beauti',
#  'hi quot get live say placemak continu attribut tenur length quot get live also featur narow scope also wrote',
#  'lot hairspray come',
#  'time',
#  'ye even funnier ask siri gender say genderless even though clearli recogn gender told confer everyon thought hilari true',
#  'rt greet comment share via',
#  'kind like ride tilt whirl get spin',
#  'war happen languag fail margaret atwood',
#  'thank work team jclair need get unsaf live condit would go long way u rn',
#  'still use mous play cd dvd',
#  'much fun one store end spend paycheck',
#  'chang wish see world mahatma gandhi word truer incred woman everi singl woman around world narishakti mannkibaat pmoindia',
#  'cri justin abt get jack russel liter last night good omg',
#  'grinnel colleg grinnellcolleg footbal die three year later win incred turnaround',
#  'everi time place order return expir item order show go thru day later ask repurchas cost',
#  'tri bend spoon imposs instead realiz truth spoon see spoon bend matrix',
#  'updat guid arduino circuitpython adafruitlearningsystem adafruit',
#  'give u univers healthcar',
#  'vacat read memoir realiz saw broadway bound spring play eugen first high school get right brighton beach memoir honest frank memoir hold back',
#  'lil combin train wit guy',
#  'baltimoreoriol hit last night citi sky gave boost home baltimor oriol nofilt aboutlastnight',
#  'absolut bat shit open kany tucker carlson interview explain wear pic ultrasound lanyard pro life lol',
#  'subscrib sure subscrib leaveittoletoya updat watch episod season subscrib season soon come till bless',
#  'still noth',
#  'sarah jane brubak phd prof criminaljustic publicpolici prevent sexual violenc need go beyond student activ major chang campu cultur climat must come administr read',
#  'news classicshihtzuhom com see',
#  'dhp mixtap click link listen mix',
#  'darth vader explain fight therapist',
#  'magic realli simpl got want someth let happyhalloween',
#  'beauti famili',
#  'caus know say',
#  'legit live u',
#  'u loud yeamon pack hit back like draymon',
#  'also runelit websit gateway error',
#  'cont someon els find import make proof concept busi idea test survey interview peopl target market see feasibl start grow busi join membership today',
#  'happi rexmanningday',
#  'everyon cool turn daredevil punchlin bad punchlin shehulk',
#  'bruh say',
#  'rt blvdbeatsdotcom new music brian cromer x creesi reenet entitl forev',
#  'love fire whether go warm hearth burn hous never tell',
#  'post photo draper utah',
#  'still still undef wordl',
#  'explor anoth perspect play new way bend breath explor play yoga journey self self self bhagavad gita suppos',
#  'two road open second facil dedic sour barrel age stratford ct beernew',
#  'post photo',
#  'legaci give perspect import rich individu life includ accomplish impact peopl place shane legaci live happi birthday alway heart',
#  'taco bell love chees quesadilla chipotl ranch grill chicken burrito cheesi gordita crunch would explod also pretti non adventur eater',
#  'watch ride babywhatbabywho img strongarm',
#  'bro run kicker ref whack lol',
#  'one person unfollow automat check',
#  'thank',
#  'commerc depart impos increas fine forc particip compani publicli admit wrongdo',
#  'team champion predict chennai super king chennaiipl',
#  'speak bless exist jcharm need help get extrem unsaf hous situat',
#  ...]

# %%
#create the word to vector
#try a 100 dimensional vector first
dim = 100
#Fit a Word2Vec model on our dataset
w2v = gensim.models.Word2Vec(sentences = X_train_sentence, vector_size = dim, window = 10, min_count = 1)

# %%
w2v.wv.most_similar('bad')
# Out:
# [('knew', 0.9966903328895569),
#  ('enough', 0.9966732859611511),
#  ('damn', 0.9957500100135803),
#  ('meant', 0.9956751465797424),
#  ('tbh', 0.9955178499221802),
#  ('cuz', 0.9952368140220642),
#  ('okay', 0.9946511387825012),
#  ('lol', 0.9945940375328064),
#  ('noth', 0.9945084452629089),
#  ('thought', 0.9943203926086426)]

# %%
len(w2v.wv.key_to_index)
# Out:
# 37890

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train_sentence)

# %%
tokenizer.word_index
# Out:
# {'get': 1,
#  'one': 2,
#  'thank': 3,
#  'love': 4,
#  'like': 5,
#  'time': 6,
#  'go': 7,
#  'new': 8,
#  'day': 9,
#  'u': 10,
#  'see': 11,
#  'year': 12,
#  'make': 13,
#  'today': 14,
#  'peopl': 15,
#  'look': 16,
#  'know': 17,
#  'good': 18,
#  'need': 19,
#  'work': 20,
#  'check': 21,
#  'come': 22,
#  'want': 23,
#  'back': 24,
#  'great': 25,
#  'would': 26,
#  'happi': 27,
#  'got': 28,
#  'think': 29,
#  'say': 30,
#  'watch': 31,
#  'right': 32,
#  'way': 33,
#  'show': 34,
#  'take': 35,
#  'life': 36,
#  'week': 37,
#  'much': 38,
#  'help': 39,
#  'best': 40,
#  'first': 41,
#  'game': 42,
#  'use': 43,
#  'thing': 44,
#  'still': 45,
#  'follow': 46,
#  'pleas': 47,
#  'person': 48,
#  'last': 49,
#  'live': 50,
#  'let': 51,
#  'feel': 52,
#  'post': 53,
#  'play': 54,
#  'even': 55,
#  'via': 56,
#  'photo': 57,
#  'friend': 58,
#  'never': 59,
#  'tri': 60,
#  'realli': 61,
#  'call': 62,
#  'alway': 63,
#  'team': 64,
#  'win': 65,
#  'start': 66,
#  'hope': 67,
#  'world': 68,
#  'could': 69,
#  'well': 70,
#  'famili': 71,
#  'th': 72,
#  'join': 73,
#  'support': 74,
#  'night': 75,
#  'also': 76,
#  'give': 77,
#  'find': 78,
#  'wait': 79,
#  'mani': 80,
#  'next': 81,
#  'keep': 82,
#  'home': 83,
#  'book': 84,
#  'everyon': 85,
#  'read': 86,
#  'free': 87,
#  'share': 88,
#  'man': 89,
#  'video': 90,
#  'miss': 91,
#  'amaz': 92,
#  'everi': 93,
#  'ever': 94,
#  'two': 95,
#  'may': 96,
#  'better': 97,
#  'talk': 98,
#  'twitter': 99,
#  'learn': 100,
#  'stop': 101,
#  'guy': 102,
#  'made': 103,
#  'chang': 104,
#  'season': 105,
#  'big': 106,
#  'tonight': 107,
#  'fun': 108,
#  'happen': 109,
#  'someon': 110,
#  'woman': 111,
#  'end': 112,
#  'sinc': 113,
#  'pm': 114,
#  'said': 115,
#  'lot': 116,
#  'vote': 117,
#  'sure': 118,
#  'month': 119,
#  'ye': 120,
#  'lol': 121,
#  'long': 122,
#  'run': 123,
#  'birthday': 124,
#  'put': 125,
#  'tell': 126,
#  'someth': 127,
#  'open': 128,
#  'final': 129,
#  'fuck': 130,
#  'part': 131,
#  'excit': 132,
#  'old': 133,
#  'stori': 134,
#  'beauti': 135,
#  'automat': 136,
#  'na': 137,
#  'favorit': 138,
#  'thought': 139,
#  'anoth': 140,
#  'busi': 141,
#  'ask': 142,
#  'sign': 143,
#  'link': 144,
#  'wish': 145,
#  'money': 146,
#  'mean': 147,
#  'news': 148,
#  'care': 149,
#  'kid': 150,
#  'around': 151,
#  'state': 152,
#  'real': 153,
#  'music': 154,
#  'octob': 155,
#  'ticket': 156,
#  'tomorrow': 157,
#  'littl': 158,
#  'commun': 159,
#  'actual': 160,
#  'tweet': 161,
#  'point': 162,
#  'movi': 163,
#  'job': 164,
#  'hey': 165,
#  'move': 166,
#  'account': 167,
#  'school': 168,
#  'hous': 169,
#  'enjoy': 170,
#  'listen': 171,
#  'servic': 172,
#  'place': 173,
#  'hour': 174,
#  'god': 175,
#  'fan': 176,
#  'hear': 177,
#  'girl': 178,
#  'found': 179,
#  'head': 180,
#  'name': 181,
#  'celebr': 182,
#  'ad': 183,
#  'bad': 184,
#  'full': 185,
#  'countri': 186,
#  'meet': 187,
#  'event': 188,
#  'anyon': 189,
#  'away': 190,
#  'special': 191,
#  'stay': 192,
#  'power': 193,
#  'episod': 194,
#  'everyth': 195,
#  'hard': 196,
#  'weekend': 197,
#  'heart': 198,
#  'word': 199,
#  'might': 200,
#  'citi': 201,
#  'bring': 202,
#  'child': 203,
#  'oh': 204,
#  'morn': 205,
#  'done': 206,
#  'without': 207,
#  'top': 208,
#  'song': 209,
#  'avail': 210,
#  'trump': 211,
#  'proud': 212,
#  'readi': 213,
#  'believ': 214,
#  'send': 215,
#  'art': 216,
#  'babi': 217,
#  'yet': 218,
#  'list': 219,
#  'w': 220,
#  'friday': 221,
#  'differ': 222,
#  'togeth': 223,
#  'shit': 224,
#  'rememb': 225,
#  'fall': 226,
#  'soon': 227,
#  'wonder': 228,
#  'congratul': 229,
#  'noth': 230,
#  'black': 231,
#  'high': 232,
#  'set': 233,
#  'interest': 234,
#  'question': 235,
#  'must': 236,
#  'face': 237,
#  'medium': 238,
#  'pay': 239,
#  'continu': 240,
#  'issu': 241,
#  'close': 242,
#  'student': 243,
#  'alreadi': 244,
#  'creat': 245,
#  'turn': 246,
#  'health': 247,
#  'anyth': 248,
#  'x': 249,
#  'updat': 250,
#  'buy': 251,
#  'unfollow': 252,
#  'ago': 253,
#  'order': 254,
#  'report': 255,
#  'gon': 256,
#  'market': 257,
#  'left': 258,
#  'moment': 259,
#  'parti': 260,
#  'seen': 261,
#  'sorri': 262,
#  'plan': 263,
#  'experi': 264,
#  'visit': 265,
#  'nation': 266,
#  'compani': 267,
#  'mayb': 268,
#  'star': 269,
#  'nice': 270,
#  'enough': 271,
#  'food': 272,
#  'absolut': 273,
#  'fight': 274,
#  'mind': 275,
#  'break': 276,
#  'offic': 277,
#  'awesom': 278,
#  'import': 279,
#  'chanc': 280,
#  'white': 281,
#  'human': 282,
#  'perform': 283,
#  'hand': 284,
#  'boy': 285,
#  'true': 286,
#  'kind': 287,
#  'onlin': 288,
#  'hit': 289,
#  'line': 290,
#  'app': 291,
#  'social': 292,
#  'sale': 293,
#  'car': 294,
#  'wrong': 295,
#  'drop': 296,
#  'offici': 297,
#  'presid': 298,
#  'bless': 299,
#  'save': 300,
#  'hi': 301,
#  'latest': 302,
#  'design': 303,
#  'forward': 304,
#  'idea': 305,
#  'lost': 306,
#  'podcast': 307,
#  'hate': 308,
#  'futur': 309,
#  'wear': 310,
#  'custom': 311,
#  'stream': 312,
#  'dog': 313,
#  'matter': 314,
#  'seri': 315,
#  'includ': 316,
#  'film': 317,
#  'cool': 318,
#  'st': 319,
#  'pretti': 320,
#  'build': 321,
#  'walk': 322,
#  'enter': 323,
#  'releas': 324,
#  'went': 325,
#  'american': 326,
#  'incred': 327,
#  'super': 328,
#  'number': 329,
#  'pick': 330,
#  'sound': 331,
#  'v': 332,
#  'rest': 333,
#  'b': 334,
#  'late': 335,
#  'caus': 336,
#  'second': 337,
#  'far': 338,
#  'inspir': 339,
#  'abl': 340,
#  'public': 341,
#  'possibl': 342,
#  'yeah': 343,
#  'p': 344,
#  'hold': 345,
#  'whole': 346,
#  'dream': 347,
#  'wow': 348,
#  'welcom': 349,
#  'step': 350,
#  'honor': 351,
#  'water': 352,
#  'minut': 353,
#  'elect': 354,
#  'kill': 355,
#  'gener': 356,
#  'price': 357,
#  'collect': 358,
#  'fact': 359,
#  'covid': 360,
#  'congrat': 361,
#  'becom': 362,
#  'phone': 363,
#  'record': 364,
#  'current': 365,
#  'messag': 366,
#  'write': 367,
#  'park': 368,
#  'least': 369,
#  'complet': 370,
#  'shot': 371,
#  'definit': 372,
#  'guess': 373,
#  'took': 374,
#  'receiv': 375,
#  'past': 376,
#  'k': 377,
#  'product': 378,
#  'earli': 379,
#  'project': 380,
#  'donat': 381,
#  'connect': 382,
#  'earn': 383,
#  'cover': 384,
#  'leav': 385,
#  'expect': 386,
#  'eat': 387,
#  'saw': 388,
#  'level': 389,
#  'le': 390,
#  'posit': 391,
#  'light': 392,
#  'els': 393,
#  'problem': 394,
#  'million': 395,
#  'speak': 396,
#  'summer': 397,
#  'train': 398,
#  'manag': 399,
#  'opportun': 400,
#  'local': 401,
#  'war': 402,
#  'fire': 403,
#  'red': 404,
#  'member': 405,
#  'saturday': 406,
#  'deal': 407,
#  'nan': 408,
#  'stand': 409,
#  'though': 410,
#  'mom': 411,
#  'bio': 412,
#  'seem': 413,
#  'group': 414,
#  'came': 415,
#  'footbal': 416,
#  'f': 417,
#  'space': 418,
#  'peac': 419,
#  'reason': 420,
#  'system': 421,
#  'law': 422,
#  'lead': 423,
#  'probabl': 424,
#  'respons': 425,
#  'action': 426,
#  'shop': 427,
#  'email': 428,
#  'america': 429,
#  'brand': 430,
#  'act': 431,
#  'c': 432,
#  'sunday': 433,
#  'tour': 434,
#  'perfect': 435,
#  'area': 436,
#  'appreci': 437,
#  'side': 438,
#  'answer': 439,
#  'allow': 440,
#  'protect': 441,
#  'crazi': 442,
#  'three': 443,
#  'histori': 444,
#  'drive': 445,
#  'cours': 446,
#  'blue': 447,
#  'safe': 448,
#  'case': 449,
#  'deserv': 450,
#  'e': 451,
#  'biden': 452,
#  'bodi': 453,
#  'announc': 454,
#  'offer': 455,
#  'class': 456,
#  'eye': 457,
#  'understand': 458,
#  'date': 459,
#  'n': 460,
#  'grow': 461,
#  'memori': 462,
#  'success': 463,
#  'men': 464,
#  'provid': 465,
#  'heard': 466,
#  'forget': 467,
#  'brother': 468,
#  'store': 469,
#  'hello': 470,
#  'lie': 471,
#  'bit': 472,
#  'young': 473,
#  'player': 474,
#  'ok': 475,
#  'other': 476,
#  'grate': 477,
#  'artist': 478,
#  'award': 479,
#  'page': 480,
#  'easi': 481,
#  'agre': 482,
#  'album': 483,
#  'click': 484,
#  'view': 485,
#  'direct': 486,
#  'glad': 487,
#  'liter': 488,
#  'damn': 489,
#  'california': 490,
#  'rais': 491,
#  'return': 492,
#  'singl': 493,
#  'featur': 494,
#  'short': 495,
#  'almost': 496,
#  'entir': 497,
#  'card': 498,
#  'interview': 499,
#  'daili': 500,
#  'recent': 501,
#  'challeng': 502,
#  'leader': 503,
#  'unit': 504,
#  'detail': 505,
#  'hot': 506,
#  'travel': 507,
#  'die': 508,
#  'as': 509,
#  'told': 510,
#  'polic': 511,
#  'room': 512,
#  'cut': 513,
#  'rock': 514,
#  'behind': 515,
#  'piec': 516,
#  'pictur': 517,
#  'access': 518,
#  'remind': 519,
#  'track': 520,
#  'present': 521,
#  'tv': 522,
#  'road': 523,
#  'lose': 524,
#  'met': 525,
#  'race': 526,
#  'septemb': 527,
#  'oct': 528,
#  'tune': 529,
#  'test': 530,
#  'educ': 531,
#  'r': 532,
#  'yesterday': 533,
#  'review': 534,
#  'self': 535,
#  'half': 536,
#  'bro': 537,
#  'sad': 538,
#  'sell': 539,
#  'finish': 540,
#  'voic': 541,
#  'halloween': 542,
#  'surpris': 543,
#  'instead': 544,
#  'articl': 545,
#  'begin': 546,
#  'polit': 547,
#  'dm': 548,
#  'host': 549,
#  'cat': 550,
#  'fit': 551,
#  'style': 552,
#  'base': 553,
#  'beat': 554,
#  'spend': 555,
#  'truli': 556,
#  'launch': 557,
#  'goal': 558,
#  'sometim': 559,
#  'christma': 560,
#  'gift': 561,
#  'contact': 562,
#  'inform': 563,
#  'hell': 564,
#  'energi': 565,
#  'republican': 566,
#  'cri': 567,
#  'process': 568,
#  'reach': 569,
#  'court': 570,
#  'worth': 571,
#  'counti': 572,
#  'fund': 573,
#  'pic': 574,
#  'street': 575,
#  'small': 576,
#  'stuff': 577,
#  'sport': 578,
#  'danc': 579,
#  'parent': 580,
#  'websit': 581,
#  'rule': 582,
#  'forev': 583,
#  'edit': 584,
#  'huge': 585,
#  'program': 586,
#  'sit': 587,
#  'charg': 588,
#  'son': 589,
#  'total': 590,
#  'queen': 591,
#  'pass': 592,
#  'york': 593,
#  'pre': 594,
#  'along': 595,
#  'giveaway': 596,
#  'govern': 597,
#  'trip': 598,
#  'youtub': 599,
#  'center': 600,
#  'smile': 601,
#  'rate': 602,
#  'comment': 603,
#  'dead': 604,
#  'charact': 605,
#  'match': 606,
#  'anim': 607,
#  'florida': 608,
#  'secur': 609,
#  'worker': 610,
#  'luck': 611,
#  'ta': 612,
#  'death': 613,
#  'exactli': 614,
#  'age': 615,
#  'air': 616,
#  'sent': 617,
#  'site': 618,
#  'loss': 619,
#  'catch': 620,
#  'code': 621,
#  'wan': 622,
#  'box': 623,
#  'clean': 624,
#  'pa': 625,
#  'im': 626,
#  'mental': 627,
#  'dad': 628,
#  'organ': 629,
#  'fix': 630,
#  'shoot': 631,
#  'data': 632,
#  'develop': 633,
#  'across': 634,
#  'hair': 635,
#  'decid': 636,
#  'outsid': 637,
#  'thursday': 638,
#  'cost': 639,
#  'career': 640,
#  'mine': 641,
#  'drink': 642,
#  'mr': 643,
#  'effect': 644,
#  'teacher': 645,
#  'journey': 646,
#  'color': 647,
#  'talent': 648,
#  'coach': 649,
#  'fast': 650,
#  'ban': 651,
#  'later': 652,
#  'imagin': 653,
#  'la': 654,
#  'laugh': 655,
#  'practic': 656,
#  'sleep': 657,
#  'especi': 658,
#  'funni': 659,
#  'limit': 660,
#  'realiz': 661,
#  'choos': 662,
#  'natur': 663,
#  'club': 664,
#  'treat': 665,
#  'gone': 666,
#  'worst': 667,
#  'dear': 668,
#  'regist': 669,
#  'omg': 670,
#  'control': 671,
#  'ya': 672,
#  'anniversari': 673,
#  'intern': 674,
#  'newprofilep': 675,
#  'beach': 676,
#  'major': 677,
#  'invest': 678,
#  'tip': 679,
#  'respect': 680,
#  'strong': 681,
#  'novemb': 682,
#  'result': 683,
#  'fli': 684,
#  'bill': 685,
#  'hire': 686,
#  'chat': 687,
#  'insid': 688,
#  'industri': 689,
#  'quit': 690,
#  'angel': 691,
#  'truth': 692,
#  'campaign': 693,
#  'score': 694,
#  'trade': 695,
#  'count': 696,
#  'consid': 697,
#  'mother': 698,
#  'front': 699,
#  'green': 700,
#  'fantast': 701,
#  'decis': 702,
#  'polici': 703,
#  'near': 704,
#  'cute': 705,
#  'clear': 706,
#  'snail': 707,
#  'low': 708,
#  'fashion': 709,
#  'west': 710,
#  'gun': 711,
#  'partner': 712,
#  'monday': 713,
#  'either': 714,
#  'festiv': 715,
#  'due': 716,
#  'add': 717,
#  'dress': 718,
#  'ukrain': 719,
#  'origin': 720,
#  'text': 721,
#  'texa': 722,
#  'holiday': 723,
#  'forc': 724,
#  'paint': 725,
#  'appli': 726,
#  'purchas': 727,
#  'impact': 728,
#  'north': 729,
#  'paid': 730,
#  'activ': 731,
#  'gave': 732,
#  'flight': 733,
#  'cancer': 734,
#  'assist': 735,
#  'stage': 736,
#  'alon': 737,
#  'stock': 738,
#  'arriv': 739,
#  'kick': 740,
#  'content': 741,
#  'convers': 742,
#  'appl': 743,
#  'soul': 744,
#  'global': 745,
#  'hurt': 746,
#  'option': 747,
#  'pray': 748,
#  'often': 749,
#  'ladi': 750,
#  'explain': 751,
#  'ga': 752,
#  'touch': 753,
#  'choic': 754,
#  'coupl': 755,
#  'bar': 756,
#  'nyc': 757,
#  'premier': 758,
#  'adventur': 759,
#  'note': 760,
#  'block': 761,
#  'john': 762,
#  'longer': 763,
#  'sister': 764,
#  'figur': 765,
#  'profession': 766,
#  'weather': 767,
#  'trust': 768,
#  'spot': 769,
#  'network': 770,
#  'info': 771,
#  'instagram': 772,
#  'type': 773,
#  'serv': 774,
#  'beyond': 775,
#  'board': 776,
#  'sweet': 777,
#  'sens': 778,
#  'fine': 779,
#  'repres': 780,
#  'pop': 781,
#  'nd': 782,
#  'version': 783,
#  'vaccin': 784,
#  'okay': 785,
#  'middl': 786,
#  'form': 787,
#  'king': 788,
#  'recommend': 789,
#  'senat': 790,
#  'dark': 791,
#  'author': 792,
#  'increas': 793,
#  'exist': 794,
#  'cast': 795,
#  'address': 796,
#  'coffe': 797,
#  'shirt': 798,
#  'g': 799,
#  'univers': 800,
#  'screen': 801,
#  'abort': 802,
#  'colleg': 803,
#  'transpond': 804,
#  'suck': 805,
#  'seat': 806,
#  'exclus': 807,
#  'leagu': 808,
#  'dude': 809,
#  'india': 810,
#  'credit': 811,
#  'mask': 812,
#  'worri': 813,
#  'ball': 814,
#  'cancel': 815,
#  'suppos': 816,
#  'magic': 817,
#  'co': 818,
#  'taken': 819,
#  'spirit': 820,
#  'bank': 821,
#  'valu': 822,
#  'locat': 823,
#  'trecru': 824,
#  'ride': 825,
#  'field': 826,
#  'london': 827,
#  'democrat': 828,
#  'daughter': 829,
#  'russia': 830,
#  'pull': 831,
#  'joy': 832,
#  'south': 833,
#  'role': 834,
#  'san': 835,
#  'effort': 836,
#  'winter': 837,
#  'lo': 838,
#  'wife': 839,
#  'sir': 840,
#  'folk': 841,
#  'plu': 842,
#  'sea': 843,
#  'term': 844,
#  'bet': 845,
#  'throw': 846,
#  'pain': 847,
#  'hang': 848,
#  'wild': 849,
#  'fear': 850,
#  'jesu': 851,
#  'rip': 852,
#  'stupid': 853,
#  'biggest': 854,
#  'claim': 855,
#  'knew': 856,
#  'whatev': 857,
#  'item': 858,
#  'floor': 859,
#  'brain': 860,
#  'attack': 861,
#  'fill': 862,
#  'band': 863,
#  'cultur': 864,
#  'com': 865,
#  'bought': 866,
#  'quick': 867,
#  'rd': 868,
#  'tire': 869,
#  'remain': 870,
#  'scene': 871,
#  'roll': 872,
#  'concert': 873,
#  'tree': 874,
#  'crime': 875,
#  'prize': 876,
#  'felt': 877,
#  'emot': 878,
#  'commit': 879,
#  'ahead': 880,
#  'land': 881,
#  'anymor': 882,
#  'research': 883,
#  'leadership': 884,
#  'relationship': 885,
#  'scienc': 886,
#  'repli': 887,
#  'four': 888,
#  'sever': 889,
#  'push': 890,
#  'uk': 891,
#  'studi': 892,
#  'former': 893,
#  'etc': 894,
#  'download': 895,
#  'attend': 896,
#  'requir': 897,
#  'brilliant': 898,
#  'tool': 899,
#  'quot': 900,
#  'ray': 901,
#  'invit': 902,
#  'prepar': 903,
#  'brought': 904,
#  'doubl': 905,
#  'medic': 906,
#  'rt': 907,
#  'joke': 908,
#  'simpl': 909,
#  'secret': 910,
#  'bag': 911,
#  'mark': 912,
#  'town': 913,
#  'healthi': 914,
#  'winner': 915,
#  'improv': 916,
#  'crew': 917,
#  'fair': 918,
#  'prayer': 919,
#  'rise': 920,
#  'grab': 921,
#  'bitch': 922,
#  'round': 923,
#  'pro': 924,
#  'platform': 925,
#  'key': 926,
#  'cash': 927,
#  'director': 928,
#  'ignor': 929,
#  'promis': 930,
#  'non': 931,
#  'benefit': 932,
#  'window': 933,
#  'privat': 934,
#  'mad': 935,
#  'pack': 936,
#  'deep': 937,
#  'door': 938,
#  'tho': 939,
#  'schedul': 940,
#  'dr': 941,
#  'trailer': 942,
#  'serious': 943,
#  'size': 944,
#  'request': 945,
#  'usa': 946,
#  'target': 947,
#  'solut': 948,
#  'drug': 949,
#  'guest': 950,
#  'giant': 951,
#  'bc': 952,
#  'promot': 953,
#  'tax': 954,
#  'haha': 955,
#  'whether': 956,
#  'deliv': 957,
#  'putin': 958,
#  'moon': 959,
#  'ur': 960,
#  'blog': 961,
#  'legend': 962,
#  'staff': 963,
#  'mention': 964,
#  'amount': 965,
#  'awar': 966,
#  'bed': 967,
#  'guid': 968,
#  'gold': 969,
#  'tech': 970,
#  'sick': 971,
#  'crash': 972,
#  'nfl': 973,
#  'tag': 974,
#  'explor': 975,
#  'channel': 976,
#  'march': 977,
#  'feder': 978,
#  'main': 979,
#  'usual': 980,
#  'teach': 981,
#  'hospit': 982,
#  'planet': 983,
#  'father': 984,
#  'digit': 985,
#  'decad': 986,
#  'justic': 987,
#  'facebook': 988,
#  'wall': 989,
#  'accept': 990,
#  'bear': 991,
#  'toward': 992,
#  'handl': 993,
#  'sold': 994,
#  'print': 995,
#  'opinion': 996,
#  'extra': 997,
#  'sun': 998,
#  'juli': 999,
#  'model': 1000,
#  ...}

# %%
#tokenize the words (this is for padding later)
X_train_tokens = tokenizer.texts_to_sequences(X_train_sentence)

# %%
#Since twitter only allows 280 characters, we shall keep the max length to
#the greater of 100 or whatever maximum length is found in the dataset
max_length = max(100, max(len(x) for x in X_train_tokens))

# %%
#Next, we can pad the sequences
X_train_tokens = pad_sequences(X_train_tokens, maxlen = max_length)

# %%
X_train_tokens.shape
# Out:
# (42947, 100)

# %%
vocabulary_size = len(tokenizer.word_index) + 1
vocab = tokenizer.word_index

# %%
#create the embedding matrix according to our word embeddings
embedding_mat = np.zeros((vocabulary_size, dim))
num_words = 0
#insert the word embeddings into our initialised object
for word, token in tokenizer.word_index.items():

    #get the corresponding vector to the word and the token
    #if the word is present in the dictionary, then we append the corresponding matrix else we continue
    if word in w2v.wv:
        vector = w2v.wv[word]
        embedding_mat[token] = vector
        num_words +=1

# %%
print(num_words, vocabulary_size)
# Out:
# 37890 37891

# %%
w2v.wv['i']
# Out:
# array([-0.00994994,  0.05659168,  0.00541038, -0.00117029, -0.01302109,
#        -0.0743858 ,  0.02437423,  0.11208599, -0.01724135, -0.03248841,
#        -0.01765264, -0.07905414, -0.03936373,  0.01748016,  0.01877048,
#        -0.04825697,  0.04178107, -0.06070923,  0.01050115, -0.12047462,
#         0.05213865,  0.02698007,  0.01679382, -0.03649551, -0.02672715,
#         0.01660547, -0.04656833, -0.03415567, -0.02553605,  0.00404084,
#         0.03856372,  0.02344867, -0.02986369, -0.04164566, -0.02026955,
#         0.02847963, -0.0239586 , -0.05074574, -0.03531399, -0.10714308,
#        -0.01250105, -0.03862583, -0.0139458 , -0.01863185,  0.03815575,
#        -0.02158216, -0.06530283, -0.01011082,  0.00289004,  0.04077569,
#         0.0254184 , -0.05409361, -0.02887317, -0.00153661, -0.02382375,
#         0.02088186,  0.02506712, -0.00692   , -0.03460557,  0.0345263 ,
#         0.0130231 , -0.00073897, -0.03044673, -0.0022704 , -0.06477474,
#         0.01851139,  0.02593491,  0.03839053, -0.07896655,  0.07778186,
#        -0.0311931 ,  0.02370988,  0.05227134, -0.02336689,  0.0589775 ,
#         0.00835457,  0.00551868,  0.00626715, -0.04913273,  0.02017129,
#        -0.03148275,  0.01245775, -0.04430048,  0.08493221,  0.00882118,
#        -0.01157024, -0.01008613,  0.07047699,  0.03629415,  0.00813164,
#         0.05907082,  0.002547  ,  0.03299638,  0.0038075 ,  0.09160181,
#         0.02661851,  0.04014744, -0.04892645,  0.04410316, -0.00255671],
#       dtype=float32)

# %%
#Since the dataset is an imbalanced dataset, we shall assign higher weights for the bot examples
#the weights assigned to the classes shall be a reciprocal of the frequencies
class_weights = {0:1.334,1:6}

# %%
#creating the neural network, starting with a relatively simple architechture
model = Sequential()
#create the embedding layer for the conversion of inputs to embedded vectors
model.add(Embedding(vocabulary_size, output_dim = dim, weights = [embedding_mat], input_length = max_length, trainable = False))
#All these LSTMS run for a 100 "timesteps" as determined by the max length parameter the units is the determine the outputsize
model.add(LSTM(units = 256, recurrent_dropout=0.3))
model.add(Dense(1, activation = 'sigmoid'))
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['acc'])

# %%
model.fit(X_train_tokens, y_train,  epochs = 8, class_weight = class_weights)
# Out:
# Epoch 1/8
# 1343/1343 [==============================] - 2753s 2s/step - loss: 1.5382 - acc: 0.5035
# Epoch 2/8
# 1343/1343 [==============================] - 1146s 853ms/step - loss: 1.5130 - acc: 0.5449
# Epoch 3/8
#  460/1343 [=========>....................] - ETA: 14:40 - loss: 1.5064 - acc: 0.5390

# %%
#applying the preprocessing steps on the test set and seeing the performance
X_test_sentence = [d.split() for d in X_test.text.tolist()]
X_test_tokens = tokenizer.texts_to_sequences(X_test_sentence)

# %%
X_test_tokens = pad_sequences(X_test_tokens, maxlen = max_length)

# %%
y_pred = np.where(model.predict(X_test_tokens) > 0.5, 1,0)

# %%
y_pred = y_pred.reshape((y_pred.shape[0],))

# %%
print(classification_report(y_test, y_pred))

# %%
confusion_matrix(y_test, y_pred)

# %%
y_train.value_counts()

# %%
y_test.value_counts()

# %%
y_pred_train = model.predict(X_train_tokens)

# %%
y_pred_train = np.where(y_pred_train > 0.5, 1,0)
y_pred_train = y_pred_train.reshape((y_pred_train.shape[0],))

# %%
print(classification_report(y_train, y_pred_train))
