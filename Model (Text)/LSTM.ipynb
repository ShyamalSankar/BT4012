# %%
import pandas as pd
import numpy as np
import nltk
import re
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM, Conv1D, MaxPool1D, BatchNormalization
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score



#We are going to use word vectorization to embed the words
import gensim

# %%
tweets = pd.read_csv('cleaned_tweets_dataset.csv')

# %% [markdown]
# # Preprocessing the tweets
# Here, we shall do things like change common short hands into full form (in order to deal with the issue of punctuation removal)

# %%
#First, we convert words like can't, won't etc into cannot and will not
short_form_dict = {
"ain't": "is not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he'll've": "he he will have",
"he's": "he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how is",
"I'd": "I would",
"I'd've": "I would have",
"I'll": "I will",
"I'll've": "I will have",
"I'm": "I am",
"I've": "I have",
"i'd": "i would",
"i'd've": "i would have",
"i'll": "i will",
"i'll've": "i will have",
"i'm": "i am",
"i've": "i have",
"isn't": "is not",
"it'd": "it would",
"it'd've": "it would have",
"it'll": "it will",
"it'll've": "it will have",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she would",
"she'd've": "she would have",
"she'll": "she will",
"she'll've": "she will have",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so as",
"that'd": "that would",
"that'd've": "that would have",
"that's": "that is",
"there'd": "there would",
"there'd've": "there would have",
"there's": "there is",
"they'd": "they would",
"they'd've": "they would have",
"they'll": "they will",
"they'll've": "they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what'll've": "what will have",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"when's": "when is",
"when've": "when have",
"where'd": "where did",
"where's": "where is",
"where've": "where have",
"who'll": "who will",
"who'll've": "who will have",
"who's": "who is",
"who've": "who have",
"why's": "why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you would",
"you'd've": "you would have",
"you'll": "you will",
"you'll've": "you will have",
"you're": "you are",
"you've": "you have",}

# %%
tweets.head()
# Out:
#              id                                     uncleaned_text  \
# 0  7.874060e+17  We can't extract the\n"Avenge" from\n"Scavenge...
# 1  7.874060e+17  We can't get the\n"Other" out of\n"Geothermal"...
# 2  7.874060e+17  You can't spell\n"Panoply"\nwithout "Ply" http...
# 3  7.874060e+17  Put the "Myrrh"\nin "Commercial" https://t.co/...
# 4  7.874060e+17  We need "Dying"\nto spell "Muddying" https://t...
#
#   account_type emoji emoji_text                                         text  \
# 0          bot    {}         []  we can t extract the avenge from scavengers
# 1          bot    {}         []     we can t get the other out of geothermal
# 2          bot    {}         []          you can t spell panoply without ply
# 3          bot    {}         []                  put the myrrh in commercial
# 4          bot    {}         []              we need dying to spell muddying
#
#                        url tags
# 0  https://t.co/FpAstfF67l   []
# 1  https://t.co/pw6xYLUph5   []
# 2  https://t.co/XYsPhTkcDX   []
# 3  https://t.co/yyadIxV48k   []
# 4  https://t.co/WJxZL1TkfM   []

# %%
#Things to keep: Capitalisation of words, punctuation, emojis and their positions

# %%
#Preprocessing steps (ie cleaning of text and including important information like emojis)

# %% [markdown]
# # Train test split, model training and word embedding

# %%
#create the X and y classes
tweets['isBot'] = 0
tweets.loc[tweets['account_type'] == 'bot', 'isBot'] = 1
y = tweets.isBot
X = tweets[['text']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
#first, just embed the cleaned tweets and see the results

#store the cleaned tweets in a list of lists representing the split
X_train_sentence = [d.split() for d in X_train.text.tolist()]

# %%
#create the word to vector
#try a 100 dimensional vector first
dim = 100
#Fit a Word2Vec model on our dataset
w2v = gensim.models.Word2Vec(sentences = X_train_sentence, vector_size = dim, window = 10, min_count = 1)

# %%
w2v.wv.most_similar('bad')
# Out:
# [('damn', 0.9481765031814575),
#  ('man', 0.9414718151092529),
#  ('honestly', 0.9409035444259644),
#  ('yeah', 0.9401690363883972),
#  ('shit', 0.9393621683120728),
#  ('sad', 0.9388050436973572),
#  ('exactly', 0.938416063785553),
#  ('funny', 0.9370057582855225),
#  ('lol', 0.9318917989730835),
#  ('oh', 0.9297439455986023)]

# %%
len(w2v.wv.key_to_index)
# Out:
# 50728

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train_sentence)

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'to': 2,
#  'a': 3,
#  'i': 4,
#  'and': 5,
#  'you': 6,
#  'of': 7,
#  'in': 8,
#  'for': 9,
#  'is': 10,
#  'it': 11,
#  's': 12,
#  'this': 13,
#  'on': 14,
#  'my': 15,
#  'that': 16,
#  'with': 17,
#  't': 18,
#  'be': 19,
#  'we': 20,
#  'at': 21,
#  'your': 22,
#  'are': 23,
#  'me': 24,
#  'have': 25,
#  'so': 26,
#  'all': 27,
#  'was': 28,
#  'can': 29,
#  'just': 30,
#  'but': 31,
#  'from': 32,
#  'not': 33,
#  'out': 34,
#  'what': 35,
#  'by': 36,
#  'one': 37,
#  'they': 38,
#  'm': 39,
#  'our': 40,
#  'as': 41,
#  'more': 42,
#  'get': 43,
#  'up': 44,
#  'if': 45,
#  'like': 46,
#  'about': 47,
#  'he': 48,
#  'do': 49,
#  'an': 50,
#  'new': 51,
#  'will': 52,
#  'now': 53,
#  'love': 54,
#  'how': 55,
#  'time': 56,
#  'when': 57,
#  'who': 58,
#  'or': 59,
#  'there': 60,
#  'no': 61,
#  'day': 62,
#  'has': 63,
#  'today': 64,
#  'thank': 65,
#  'people': 66,
#  'here': 67,
#  're': 68,
#  'don': 69,
#  'see': 70,
#  'been': 71,
#  'good': 72,
#  'us': 73,
#  'know': 74,
#  'their': 75,
#  'his': 76,
#  'back': 77,
#  'great': 78,
#  'would': 79,
#  'go': 80,
#  'some': 81,
#  've': 82,
#  'her': 83,
#  'she': 84,
#  '2': 85,
#  'happy': 86,
#  'them': 87,
#  'had': 88,
#  'make': 89,
#  'need': 90,
#  'only': 91,
#  'much': 92,
#  'got': 93,
#  'first': 94,
#  'best': 95,
#  '1': 96,
#  'thanks': 97,
#  'way': 98,
#  'right': 99,
#  'still': 100,
#  'year': 101,
#  'want': 102,
#  'over': 103,
#  'work': 104,
#  'why': 105,
#  '3': 106,
#  'life': 107,
#  'going': 108,
#  'these': 109,
#  'think': 110,
#  'week': 111,
#  'check': 112,
#  'please': 113,
#  'too': 114,
#  'll': 115,
#  'last': 116,
#  'help': 117,
#  'should': 118,
#  'show': 119,
#  'than': 120,
#  'years': 121,
#  'via': 122,
#  'very': 123,
#  'am': 124,
#  'let': 125,
#  'after': 126,
#  'were': 127,
#  'really': 128,
#  'never': 129,
#  'did': 130,
#  'always': 131,
#  'him': 132,
#  '5': 133,
#  'game': 134,
#  'because': 135,
#  'even': 136,
#  'being': 137,
#  'take': 138,
#  'off': 139,
#  'into': 140,
#  'could': 141,
#  'well': 142,
#  'person': 143,
#  'look': 144,
#  'world': 145,
#  'any': 146,
#  'live': 147,
#  'also': 148,
#  'come': 149,
#  'next': 150,
#  'many': 151,
#  'where': 152,
#  'then': 153,
#  'photo': 154,
#  'other': 155,
#  'everyone': 156,
#  'd': 157,
#  'most': 158,
#  'team': 159,
#  'down': 160,
#  'say': 161,
#  'watch': 162,
#  'night': 163,
#  'every': 164,
#  '10': 165,
#  'home': 166,
#  'find': 167,
#  'family': 168,
#  'two': 169,
#  'win': 170,
#  'free': 171,
#  'better': 172,
#  'may': 173,
#  'those': 174,
#  'amazing': 175,
#  'ever': 176,
#  '4': 177,
#  'hope': 178,
#  'made': 179,
#  'man': 180,
#  'again': 181,
#  'tonight': 182,
#  'twitter': 183,
#  'join': 184,
#  'keep': 185,
#  'support': 186,
#  'before': 187,
#  'u': 188,
#  'posted': 189,
#  'big': 190,
#  'things': 191,
#  'someone': 192,
#  'same': 193,
#  'fun': 194,
#  'friends': 195,
#  'since': 196,
#  'which': 197,
#  'feel': 198,
#  'video': 199,
#  'its': 200,
#  'lol': 201,
#  'season': 202,
#  'thing': 203,
#  'said': 204,
#  'long': 205,
#  'through': 206,
#  'days': 207,
#  'use': 208,
#  'yes': 209,
#  'getting': 210,
#  'something': 211,
#  'checked': 212,
#  'sure': 213,
#  'news': 214,
#  '6': 215,
#  'play': 216,
#  'wait': 217,
#  'read': 218,
#  'old': 219,
#  '2022': 220,
#  'birthday': 221,
#  'while': 222,
#  'looking': 223,
#  'does': 224,
#  'doing': 225,
#  'stop': 226,
#  'another': 227,
#  'automatically': 228,
#  'coming': 229,
#  'book': 230,
#  'little': 231,
#  'around': 232,
#  'part': 233,
#  'money': 234,
#  'give': 235,
#  'didn': 236,
#  'real': 237,
#  'favorite': 238,
#  '7': 239,
#  'tomorrow': 240,
#  'lot': 241,
#  'october': 242,
#  'excited': 243,
#  'own': 244,
#  'hey': 245,
#  'music': 246,
#  'beautiful': 247,
#  'such': 248,
#  'share': 249,
#  'learn': 250,
#  'tell': 251,
#  'start': 252,
#  '8': 253,
#  'y': 254,
#  'put': 255,
#  'bad': 256,
#  'link': 257,
#  'call': 258,
#  'anyone': 259,
#  'miss': 260,
#  'found': 261,
#  'away': 262,
#  'doesn': 263,
#  'watching': 264,
#  'full': 265,
#  'ready': 266,
#  'oh': 267,
#  'both': 268,
#  'school': 269,
#  'trying': 270,
#  'having': 271,
#  'hard': 272,
#  'business': 273,
#  'weekend': 274,
#  'proud': 275,
#  'morning': 276,
#  'guys': 277,
#  'done': 278,
#  'change': 279,
#  'special': 280,
#  'working': 281,
#  'story': 282,
#  'friday': 283,
#  'without': 284,
#  'everything': 285,
#  'god': 286,
#  'already': 287,
#  'shit': 288,
#  'hear': 289,
#  'women': 290,
#  'followed': 291,
#  'might': 292,
#  'actually': 293,
#  'nothing': 294,
#  'house': 295,
#  'thought': 296,
#  'few': 297,
#  'vote': 298,
#  'making': 299,
#  'available': 300,
#  'won': 301,
#  'soon': 302,
#  'yet': 303,
#  'tickets': 304,
#  'end': 305,
#  'talk': 306,
#  'w': 307,
#  'must': 308,
#  'art': 309,
#  'care': 310,
#  'health': 311,
#  'kids': 312,
#  'friend': 313,
#  'times': 314,
#  'top': 315,
#  'service': 316,
#  'follow': 317,
#  'trump': 318,
#  'month': 319,
#  'open': 320,
#  'sorry': 321,
#  'place': 322,
#  'together': 323,
#  'episode': 324,
#  'country': 325,
#  'needs': 326,
#  'until': 327,
#  'during': 328,
#  'anything': 329,
#  'congratulations': 330,
#  'believe': 331,
#  'looks': 332,
#  'stay': 333,
#  'movie': 334,
#  'finally': 335,
#  'city': 336,
#  'try': 337,
#  'black': 338,
#  '30': 339,
#  'maybe': 340,
#  'state': 341,
#  'heart': 342,
#  'remember': 343,
#  'high': 344,
#  'enough': 345,
#  'ago': 346,
#  'account': 347,
#  'point': 348,
#  'name': 349,
#  'says': 350,
#  'against': 351,
#  'media': 352,
#  'makes': 353,
#  'left': 354,
#  'community': 355,
#  'job': 356,
#  'true': 357,
#  'hi': 358,
#  'seen': 359,
#  'baby': 360,
#  'listen': 361,
#  'guy': 362,
#  'loved': 363,
#  'song': 364,
#  'food': 365,
#  'latest': 366,
#  'gonna': 367,
#  'awesome': 368,
#  'used': 369,
#  'series': 370,
#  'post': 371,
#  'party': 372,
#  '9': 373,
#  'run': 374,
#  'tweet': 375,
#  'sign': 376,
#  'isn': 377,
#  'chance': 378,
#  'wish': 379,
#  'girl': 380,
#  'each': 381,
#  'set': 382,
#  'head': 383,
#  'online': 384,
#  'cool': 385,
#  'far': 386,
#  'lost': 387,
#  'fall': 388,
#  'nice': 389,
#  'went': 390,
#  'children': 391,
#  'wrong': 392,
#  'event': 393,
#  'enjoy': 394,
#  'wow': 395,
#  'white': 396,
#  'once': 397,
#  'forward': 398,
#  'social': 399,
#  'bring': 400,
#  '0': 401,
#  'mean': 402,
#  'future': 403,
#  'power': 404,
#  '100': 405,
#  'app': 406,
#  'visit': 407,
#  'super': 408,
#  'president': 409,
#  'pretty': 410,
#  'kind': 411,
#  'rest': 412,
#  'experience': 413,
#  'saying': 414,
#  'yeah': 415,
#  'else': 416,
#  'x': 417,
#  'congrats': 418,
#  'fuck': 419,
#  'whole': 420,
#  'football': 421,
#  'moment': 422,
#  'able': 423,
#  'buy': 424,
#  'list': 425,
#  'order': 426,
#  'face': 427,
#  'important': 428,
#  'took': 429,
#  '11': 430,
#  'hours': 431,
#  '20': 432,
#  '12': 433,
#  'mind': 434,
#  'taking': 435,
#  'different': 436,
#  'using': 437,
#  'hit': 438,
#  'unfollowed': 439,
#  'called': 440,
#  'past': 441,
#  'line': 442,
#  'playing': 443,
#  'games': 444,
#  'yourself': 445,
#  'meet': 446,
#  'thinking': 447,
#  'bio': 448,
#  'woman': 449,
#  'early': 450,
#  'fans': 451,
#  'least': 452,
#  'seeing': 453,
#  'saw': 454,
#  'matter': 455,
#  'covid': 456,
#  'weeks': 457,
#  'haven': 458,
#  'fucking': 459,
#  'under': 460,
#  'crazy': 461,
#  'though': 462,
#  'words': 463,
#  'red': 464,
#  'water': 465,
#  'late': 466,
#  'myself': 467,
#  'men': 468,
#  'between': 469,
#  'local': 470,
#  'less': 471,
#  'sunday': 472,
#  'three': 473,
#  'almost': 474,
#  'phone': 475,
#  'company': 476,
#  'public': 477,
#  'came': 478,
#  'waiting': 479,
#  'absolutely': 480,
#  'america': 481,
#  'second': 482,
#  'definitely': 483,
#  'saturday': 484,
#  'national': 485,
#  'history': 486,
#  'car': 487,
#  'human': 488,
#  'talking': 489,
#  'peace': 490,
#  'wanted': 491,
#  'incredible': 492,
#  'probably': 493,
#  'gets': 494,
#  'sale': 495,
#  'young': 496,
#  'students': 497,
#  'easy': 498,
#  'hot': 499,
#  'hate': 500,
#  'summer': 501,
#  'pay': 502,
#  'podcast': 503,
#  '15': 504,
#  'heard': 505,
#  'hello': 506,
#  'giving': 507,
#  'idea': 508,
#  'send': 509,
#  'ok': 510,
#  'guess': 511,
#  'welcome': 512,
#  'safe': 513,
#  'fan': 514,
#  'close': 515,
#  'forget': 516,
#  '000': 517,
#  'wasn': 518,
#  'others': 519,
#  'move': 520,
#  'ask': 521,
#  'shows': 522,
#  'wants': 523,
#  'mom': 524,
#  'office': 525,
#  'tour': 526,
#  'told': 527,
#  'yesterday': 528,
#  'space': 529,
#  'months': 530,
#  'feeling': 531,
#  'behind': 532,
#  'police': 533,
#  'perfect': 534,
#  'glad': 535,
#  'possible': 536,
#  'literally': 537,
#  'daily': 538,
#  'grateful': 539,
#  'single': 540,
#  'ass': 541,
#  'war': 542,
#  'small': 543,
#  'b': 544,
#  'cannot': 545,
#  'california': 546,
#  'body': 547,
#  'boy': 548,
#  'park': 549,
#  'lives': 550,
#  'wonderful': 551,
#  'number': 552,
#  'cause': 553,
#  'bit': 554,
#  'issue': 555,
#  'living': 556,
#  'level': 557,
#  'biden': 558,
#  'american': 559,
#  'film': 560,
#  'fight': 561,
#  'question': 562,
#  'started': 563,
#  'damn': 564,
#  'comes': 565,
#  'below': 566,
#  'course': 567,
#  'means': 568,
#  'instead': 569,
#  'goes': 570,
#  'along': 571,
#  'album': 572,
#  'star': 573,
#  'project': 574,
#  'photos': 575,
#  'september': 576,
#  'case': 577,
#  'truly': 578,
#  'oct': 579,
#  'save': 580,
#  'side': 581,
#  'action': 582,
#  'celebrate': 583,
#  'running': 584,
#  'website': 585,
#  'opportunity': 586,
#  '22': 587,
#  'details': 588,
#  'n': 589,
#  'tv': 590,
#  'ones': 591,
#  'update': 592,
#  'area': 593,
#  'problem': 594,
#  'class': 595,
#  '24': 596,
#  'luck': 597,
#  'report': 598,
#  'rights': 599,
#  'shot': 600,
#  'click': 601,
#  'pre': 602,
#  'happened': 603,
#  'entire': 604,
#  'group': 605,
#  '19': 606,
#  'stuff': 607,
#  'sad': 608,
#  'room': 609,
#  'official': 610,
#  'halloween': 611,
#  'york': 612,
#  'half': 613,
#  'christmas': 614,
#  'ad': 615,
#  'brand': 616,
#  'e': 617,
#  'break': 618,
#  'energy': 619,
#  'reading': 620,
#  'gotta': 621,
#  'data': 622,
#  'hell': 623,
#  'forever': 624,
#  'self': 625,
#  'across': 626,
#  '14': 627,
#  'books': 628,
#  'pm': 629,
#  'road': 630,
#  'brother': 631,
#  'short': 632,
#  'market': 633,
#  'journey': 634,
#  'shop': 635,
#  'hold': 636,
#  'release': 637,
#  'f': 638,
#  'dog': 639,
#  'word': 640,
#  'light': 641,
#  'blue': 642,
#  'page': 643,
#  'missed': 644,
#  'sometimes': 645,
#  'fire': 646,
#  '50': 647,
#  'hour': 648,
#  'store': 649,
#  'continue': 650,
#  'court': 651,
#  'huge': 652,
#  'florida': 653,
#  'im': 654,
#  'access': 655,
#  'dead': 656,
#  'thursday': 657,
#  'collection': 658,
#  'needed': 659,
#  'youtube': 660,
#  'starting': 661,
#  'exactly': 662,
#  'system': 663,
#  'girls': 664,
#  'hair': 665,
#  'air': 666,
#  'walk': 667,
#  'fact': 668,
#  'happen': 669,
#  'plan': 670,
#  'step': 671,
#  'cover': 672,
#  'funny': 673,
#  'minutes': 674,
#  'sending': 675,
#  'agree': 676,
#  'couldn': 677,
#  'final': 678,
#  'west': 679,
#  'wanna': 680,
#  'added': 681,
#  'understand': 682,
#  'pick': 683,
#  'stories': 684,
#  'message': 685,
#  'million': 686,
#  'yours': 687,
#  'email': 688,
#  'newprofilepic': 689,
#  'turn': 690,
#  'leave': 691,
#  'giveaway': 692,
#  'dm': 693,
#  '18': 694,
#  'interested': 695,
#  'seems': 696,
#  'customer': 697,
#  'including': 698,
#  'fantastic': 699,
#  'worst': 700,
#  'ya': 701,
#  'son': 702,
#  'piece': 703,
#  'contact': 704,
#  'enter': 705,
#  'sent': 706,
#  'especially': 707,
#  'appreciate': 708,
#  'worth': 709,
#  'voice': 710,
#  'center': 711,
#  '21': 712,
#  'c': 713,
#  'eat': 714,
#  'paid': 715,
#  'later': 716,
#  'sharing': 717,
#  'front': 718,
#  'anniversary': 719,
#  'law': 720,
#  'following': 721,
#  'tried': 722,
#  '1st': 723,
#  'bro': 724,
#  'vs': 725,
#  'fast': 726,
#  'followers': 727,
#  'strong': 728,
#  'honor': 729,
#  'career': 730,
#  '13': 731,
#  'states': 732,
#  'omg': 733,
#  'loving': 734,
#  'gone': 735,
#  'death': 736,
#  'county': 737,
#  'texas': 738,
#  'answer': 739,
#  'trip': 740,
#  'become': 741,
#  'content': 742,
#  'queen': 743,
#  'dear': 744,
#  'works': 745,
#  'monday': 746,
#  'building': 747,
#  'dad': 748,
#  'date': 749,
#  'street': 750,
#  'deal': 751,
#  'drop': 752,
#  'watched': 753,
#  'child': 754,
#  'code': 755,
#  'r': 756,
#  'reason': 757,
#  'mental': 758,
#  'loss': 759,
#  'election': 760,
#  'green': 761,
#  'november': 762,
#  '2020': 763,
#  'article': 764,
#  'instagram': 765,
#  'played': 766,
#  'price': 767,
#  'campaign': 768,
#  'interview': 769,
#  'performance': 770,
#  'longer': 771,
#  'issues': 772,
#  'ukraine': 773,
#  'record': 774,
#  'add': 775,
#  'race': 776,
#  'due': 777,
#  'hand': 778,
#  'dream': 779,
#  'either': 780,
#  'create': 781,
#  '99': 782,
#  'act': 783,
#  'stand': 784,
#  'response': 785,
#  'outside': 786,
#  'stream': 787,
#  'beach': 788,
#  'wearing': 789,
#  'fine': 790,
#  '25': 791,
#  'cancer': 792,
#  'often': 793,
#  'sweet': 794,
#  'card': 795,
#  'asked': 796,
#  'families': 797,
#  'site': 798,
#  'o': 799,
#  'questions': 800,
#  'beyond': 801,
#  'workers': 802,
#  'takes': 803,
#  'meeting': 804,
#  'gift': 805,
#  'learning': 806,
#  'p': 807,
#  'london': 808,
#  'weather': 809,
#  'snail': 810,
#  'inside': 811,
#  'truth': 812,
#  'cat': 813,
#  'review': 814,
#  'okay': 815,
#  'fashion': 816,
#  'mr': 817,
#  'knew': 818,
#  'aren': 819,
#  'wife': 820,
#  'pass': 821,
#  'info': 822,
#  'beat': 823,
#  'lovely': 824,
#  'middle': 825,
#  'club': 826,
#  'thoughts': 827,
#  'north': 828,
#  'student': 829,
#  'alone': 830,
#  'calling': 831,
#  'personal': 832,
#  'whatever': 833,
#  'mother': 834,
#  'sound': 835,
#  'ain': 836,
#  'four': 837,
#  'rock': 838,
#  'apple': 839,
#  'choose': 840,
#  'feels': 841,
#  'transponder': 842,
#  'picture': 843,
#  'government': 844,
#  'cute': 845,
#  'parents': 846,
#  'happening': 847,
#  'box': 848,
#  'south': 849,
#  'sounds': 850,
#  'mine': 851,
#  'united': 852,
#  'gave': 853,
#  'catch': 854,
#  'taken': 855,
#  'low': 856,
#  'jobs': 857,
#  'chat': 858,
#  'sense': 859,
#  'king': 860,
#  '00': 861,
#  'wear': 862,
#  'dude': 863,
#  'healthy': 864,
#  'register': 865,
#  'trecru': 866,
#  'clear': 867,
#  'global': 868,
#  'ways': 869,
#  'la': 870,
#  'lots': 871,
#  'russia': 872,
#  '2023': 873,
#  'college': 874,
#  'lose': 875,
#  'smile': 876,
#  'success': 877,
#  'wild': 878,
#  'couple': 879,
#  'interesting': 880,
#  'cut': 881,
#  'nyc': 882,
#  'john': 883,
#  'plus': 884,
#  'current': 885,
#  'india': 886,
#  'near': 887,
#  'program': 888,
#  'rip': 889,
#  'view': 890,
#  'wouldn': 891,
#  'process': 892,
#  'san': 893,
#  'dr': 894,
#  'currently': 895,
#  'based': 896,
#  'boys': 897,
#  'eyes': 898,
#  'met': 899,
#  'policy': 900,
#  'style': 901,
#  'ticket': 902,
#  'brilliant': 903,
#  'bought': 904,
#  'information': 905,
#  'design': 906,
#  'return': 907,
#  'imagine': 908,
#  'speak': 909,
#  'brain': 910,
#  '16': 911,
#  'grow': 912,
#  'ahead': 913,
#  'drive': 914,
#  'videos': 915,
#  'worked': 916,
#  'write': 917,
#  'felt': 918,
#  'choice': 919,
#  'test': 920,
#  'etc': 921,
#  'sleep': 922,
#  'international': 923,
#  'changed': 924,
#  'track': 925,
#  'build': 926,
#  'putting': 927,
#  '2018': 928,
#  'talent': 929,
#  'stupid': 930,
#  'kid': 931,
#  'killed': 932,
#  'biggest': 933,
#  'league': 934,
#  'industry': 935,
#  'streaming': 936,
#  'rt': 937,
#  'bill': 938,
#  'com': 939,
#  'listening': 940,
#  'age': 941,
#  'jesus': 942,
#  'dance': 943,
#  'leaders': 944,
#  'celebrating': 945,
#  'writing': 946,
#  'lead': 947,
#  'fix': 948,
#  'flight': 949,
#  'ban': 950,
#  'brought': 951,
#  'stage': 952,
#  'deserve': 953,
#  'simple': 954,
#  'credit': 955,
#  'tho': 956,
#  'match': 957,
#  'coffee': 958,
#  'seriously': 959,
#  'justice': 960,
#  'education': 961,
#  'apply': 962,
#  'wishing': 963,
#  'leadership': 964,
#  'gives': 965,
#  'marketing': 966,
#  'members': 967,
#  'winter': 968,
#  'artist': 969,
#  'uk': 970,
#  'voting': 971,
#  'opening': 972,
#  'touch': 973,
#  'joy': 974,
#  'created': 975,
#  'goal': 976,
#  'facebook': 977,
#  '40': 978,
#  'events': 979,
#  'ball': 980,
#  'training': 981,
#  'teams': 982,
#  'movies': 983,
#  'offer': 984,
#  '23': 985,
#  'role': 986,
#  'former': 987,
#  'sir': 988,
#  'research': 989,
#  'evening': 990,
#  'joined': 991,
#  'prices': 992,
#  'cold': 993,
#  'asking': 994,
#  'abortion': 995,
#  'holiday': 996,
#  'quick': 997,
#  'trailer': 998,
#  'winning': 999,
#  'happens': 1000,
#  ...}

# %%
#tokenize the words (this is for padding later)
X_train_tokens = tokenizer.texts_to_sequences(X_train_sentence)

# %%
#Since twitter only allows 280 characters, we shall keep the max length to
#the greater of 100 or whatever maximum length is found in the dataset
max_length = max(100, max(len(x) for x in X_train_tokens))

# %%
#Next, we can pad the sequences
X_train_tokens = pad_sequences(X_train_tokens, maxlen = max_length)

# %%
X_train_tokens.shape
# Out:
# (42947, 100)

# %%
vocabulary_size = len(tokenizer.word_index) + 1
vocab = tokenizer.word_index

# %%
#create the embedding matrix according to our word embeddings
embedding_mat = np.zeros((vocabulary_size, dim))
num_words = 0
#insert the word embeddings into our initialised object
for word, token in tokenizer.word_index.items():

    #get the corresponding vector to the word and the token
    #if the word is present in the dictionary, then we append the corresponding matrix else we continue
    if word in w2v.wv:
        vector = w2v.wv[word]
        embedding_mat[token] = vector
        num_words +=1

# %%
print(num_words, vocabulary_size)
# Out:
# 50728 50729

# %%
w2v.wv['i']
# Out:
# array([-2.3992848 ,  3.1841776 ,  1.2062366 , -1.9689982 ,  1.051914  ,
#        -2.9550207 ,  2.6452806 ,  3.466314  ,  1.2474681 , -0.6973632 ,
#         1.2842598 , -1.6237582 ,  2.0778978 , -0.04110769,  0.43601024,
#        -1.6178536 ,  2.0111864 , -0.5543657 , -1.0898633 , -0.5951887 ,
#         1.119117  , -1.5618718 ,  1.6210287 ,  1.0846449 , -2.7858665 ,
#         0.43388546,  2.809095  , -0.5093762 , -1.0577548 ,  0.21375081,
#         2.579838  , -1.1874669 ,  1.3204618 , -0.24106614, -0.15340355,
#         1.8027278 ,  2.8504913 , -0.7817102 , -1.4898494 ,  1.1824074 ,
#         2.1488767 ,  0.7653103 ,  0.7508155 , -0.62070227,  2.2415252 ,
#         0.09766399,  0.3771947 ,  0.19460534,  0.569336  , -1.0239731 ,
#         0.18750551, -1.0761305 , -0.42708784, -2.7616012 , -1.3874998 ,
#         2.8107812 , -0.22384486,  1.0448225 , -0.04655965, -0.5599327 ,
#         1.3539746 ,  0.50677794,  1.5367647 ,  1.572473  ,  0.73857605,
#        -1.3069929 ,  0.08728168,  2.0257118 , -2.5137622 ,  0.9691612 ,
#         0.65584534, -0.15401857,  2.158105  ,  3.6495445 ,  1.8761894 ,
#        -0.05685918, -0.18167795,  1.5018505 ,  0.47208804,  0.4541596 ,
#        -1.3949478 ,  1.6396447 , -0.9279223 ,  3.6840906 , -2.3941798 ,
#        -1.5162195 ,  3.0296626 ,  0.6046917 ,  1.6642162 , -0.8098459 ,
#         0.79013896,  1.209222  , -0.5937719 , -1.1635572 ,  1.877624  ,
#         0.25763935,  0.9078356 , -2.80904   ,  0.31934997, -1.4542224 ],
#       dtype=float32)

# %%
#Since the dataset is an imbalanced dataset, we shall assign higher weights for the bot examples
#the weights assigned to the classes shall be a reciprocal of the frequencies
class_weights = {0:1.334,1:5}

# %%
#creating the neural network, starting with a relatively simple architechture
model = Sequential()
#create the embedding layer for the conversion of inputs to embedded vectors
model.add(Embedding(vocabulary_size, output_dim = dim, weights = [embedding_mat], input_length = max_length, trainable = False))
#All these LSTMS run for a 100 "timesteps" as determined by the max length parameter the units is the determine the outputsize
model.add(LSTM(units = 256, recurrent_dropout=0.3))
model.add(Dense(1, activation = 'sigmoid'))
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['acc'])

# %%
model.fit(X_train_tokens, y_train,  epochs = 8, class_weight = class_weights)
# Out:
# Epoch 1/8
# 1343/1343 [==============================] - 677s 502ms/step - loss: 1.3780 - acc: 0.6480
# Epoch 2/8
# 1343/1343 [==============================] - 727s 541ms/step - loss: 1.3384 - acc: 0.6693
# Epoch 3/8
# 1343/1343 [==============================] - 820s 611ms/step - loss: 1.3152 - acc: 0.6794
# Epoch 4/8
# 1343/1343 [==============================] - 800s 596ms/step - loss: 1.2970 - acc: 0.6838
# Epoch 5/8
# 1343/1343 [==============================] - 727s 541ms/step - loss: 1.2747 - acc: 0.6949
# Epoch 6/8
# 1343/1343 [==============================] - 597s 445ms/step - loss: 1.2500 - acc: 0.7038
# Epoch 7/8
# 1343/1343 [==============================] - 1971s 1s/step - loss: 1.2173 - acc: 0.7162
# Epoch 8/8
# 1343/1343 [==============================] - 726s 541ms/step - loss: 1.1844 - acc: 0.7226

# %%
#applying the preprocessing steps on the test set and seeing the performance
X_test_sentence = [d.split() for d in X_test.text.tolist()]
X_test_tokens = tokenizer.texts_to_sequences(X_test_sentence)

# %%
X_test_tokens = pad_sequences(X_test_tokens, maxlen = max_length)

# %%
y_pred = np.where(model.predict(X_test_tokens) > 0.5, 1,0)
# Out:
# 336/336 [==============================] - 39s 113ms/step

# %%
y_pred = y_pred.reshape((y_pred.shape[0],))

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.72      0.78      8527
#            1       0.34      0.55      0.42      2210
#
#     accuracy                           0.69     10737
#    macro avg       0.60      0.64      0.60     10737
# weighted avg       0.75      0.69      0.71     10737

# %%
y_pred_train = model.predict(X_train_tokens)
# Out:
# 1343/1343 [==============================] - 134s 100ms/step

# %%
y_pred_train = np.where(y_pred_train > 0.5, 1,0)
y_pred_train = y_pred_train.reshape((y_pred_train.shape[0],))

# %%
print(classification_report(y_train, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.76      0.83     34385
#            1       0.42      0.70      0.52      8562
#
#     accuracy                           0.75     42947
#    macro avg       0.66      0.73      0.68     42947
# weighted avg       0.81      0.75      0.77     42947
