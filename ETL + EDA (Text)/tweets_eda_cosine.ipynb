# %%
# Hashtags
import pandas as pd
tweets = pd.read_csv("cleaned_tweets_dataset.csv")


import re
def hashtags_in_tweet(df):
    df['hashtags'] =''
    for word in range(len(df)):
        tweet = df["uncleaned_text"][word]
        tweet_clean = df['text'][word]
        tweet.replace('\n', " ")
        word_list = tweet.split(' ')
        word_list2 = tweet_clean.split(' ')
        regex = "#(\w+)"
        hashtag_list = re.findall(regex, tweet)
        for i in range(len(word_list2.copy())):
            hashtag_list_lower = [item.lower() for item in hashtag_list]
            if word_list2.copy()[i] in hashtag_list_lower:
                word_list2[i] = word_list2.copy()[i]
        new_tweet = " ".join(word_list2)
        df['text'][word] = new_tweet
        df["hashtags"][word] = hashtag_list
    return df

tweets = hashtags_in_tweet(tweets)
tweets
# Out:
# /var/folders/cw/msb46c3s00b97g2_cw34t0100000gn/T/ipykernel_7402/3466396034.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'][word] = new_tweet
# /var/folders/cw/msb46c3s00b97g2_cw34t0100000gn/T/ipykernel_7402/3466396034.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["hashtags"][word] = hashtag_list
#                  id                                     uncleaned_text  \
# 0      7.874060e+17  We can't extract the\n"Avenge" from\n"Scavenge...
# 1      7.874060e+17  We can't get the\n"Other" out of\n"Geothermal"...
# 2      7.874060e+17  You can't spell\n"Panoply"\nwithout "Ply" http...
# 3      7.874060e+17  Put the "Myrrh"\nin "Commercial" https://t.co/...
# 4      7.874060e+17  We need "Dying"\nto spell "Muddying" https://t...
# ...             ...                                                ...
# 53679  5.870357e+08  Lung Cancer: Help Make the Invisible Disease V...
# 53680  5.870357e+08  Can Mushrooms Help the Immune System Fight Can...
# 53681  3.259070e+09  @davidhelman_ @CowboysNation For real! Holy **...
# 53682  3.259070e+09      @UberFacts They paid $2.5 million. #uberfacts
# 53683  5.241212e+08  Choreography Mashup ll 🎁\n\n#achahakyeon #Chor...
#
#       account_type                  emoji        emoji_text  \
# 0              bot                     {}                []
# 1              bot                     {}                []
# 2              bot                     {}                []
# 3              bot                     {}                []
# 4              bot                     {}                []
# ...            ...                    ...               ...
# 53679          bot                     {}                []
# 53680          bot                     {}                []
# 53681        human                     {}                []
# 53682        human                     {}                []
# 53683        human  {'🎁': 'wrapped_gift'}  ['wrapped_gift']
#
#                                                     text  \
# 0            we can t extract the avenge from scavengers
# 1               we can t get the other out of geothermal
# 2                    you can t spell panoply without ply
# 3                            put the myrrh in commercial
# 4                        we need dying to spell muddying
# ...                                                  ...
# 53679  lung cancer help make the invisible disease vi...
# 53680  can mushrooms help the immune system fight can...
# 53681  for real holy i don t understand how so many p...
# 53682                    they paid 2 5 million uberfacts
# 53683  choreography mashup ll achahakyeon choreograph...
#
#                            url                                 tags  \
# 0      https://t.co/FpAstfF67l                                   []
# 1      https://t.co/pw6xYLUph5                                   []
# 2      https://t.co/XYsPhTkcDX                                   []
# 3      https://t.co/yyadIxV48k                                   []
# 4      https://t.co/WJxZL1TkfM                                   []
# ...                        ...                                  ...
# 53679  https://t.co/IB1idH6a9B                                   []
# 53680  https://t.co/9uQR8dN1cA                                   []
# 53681                      NaN  ['@davidhelman_', '@CowboysNation']
# 53682                      NaN                       ['@UberFacts']
# 53683  https://t.co/ZfG2oqGCGy                                   []
#
#                                 hashtags
# 0                                     []
# 1                                     []
# 2                                     []
# 3                                     []
# 4                                     []
# ...                                  ...
# 53679           [WorldCancerDay, health]
# 53680           [WorldCancerDay, health]
# 53681                                 []
# 53682                        [uberfacts]
# 53683  [achahakyeon, ChoreographyMashup]
#
# [53684 rows x 9 columns]

# %%
tweets['hashtags']
tweets
def remove_numbers(df):
    for word in range(len(df)):
        pattern = '[0-9]'
        tweet_clean = df['text'][word].split(' ')
        tweet_clean = [re.sub(pattern, '', i) for i in tweet_clean]
        new_tweet = " ".join(tweet_clean)
        df['text'][word] = new_tweet
    return df
tweets = remove_numbers(tweets)
# Out:
# /var/folders/cw/msb46c3s00b97g2_cw34t0100000gn/T/ipykernel_7402/2528012861.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'][word] = new_tweet

# %%
tweets
# Out:
#                  id                                     uncleaned_text  \
# 0      7.874060e+17  We can't extract the\n"Avenge" from\n"Scavenge...
# 1      7.874060e+17  We can't get the\n"Other" out of\n"Geothermal"...
# 2      7.874060e+17  You can't spell\n"Panoply"\nwithout "Ply" http...
# 3      7.874060e+17  Put the "Myrrh"\nin "Commercial" https://t.co/...
# 4      7.874060e+17  We need "Dying"\nto spell "Muddying" https://t...
# ...             ...                                                ...
# 53679  5.870357e+08  Lung Cancer: Help Make the Invisible Disease V...
# 53680  5.870357e+08  Can Mushrooms Help the Immune System Fight Can...
# 53681  3.259070e+09  @davidhelman_ @CowboysNation For real! Holy **...
# 53682  3.259070e+09      @UberFacts They paid $2.5 million. #uberfacts
# 53683  5.241212e+08  Choreography Mashup ll 🎁\n\n#achahakyeon #Chor...
#
#       account_type                  emoji        emoji_text  \
# 0              bot                     {}                []
# 1              bot                     {}                []
# 2              bot                     {}                []
# 3              bot                     {}                []
# 4              bot                     {}                []
# ...            ...                    ...               ...
# 53679          bot                     {}                []
# 53680          bot                     {}                []
# 53681        human                     {}                []
# 53682        human                     {}                []
# 53683        human  {'🎁': 'wrapped_gift'}  ['wrapped_gift']
#
#                                                     text  \
# 0            we can t extract the avenge from scavengers
# 1               we can t get the other out of geothermal
# 2                    you can t spell panoply without ply
# 3                            put the myrrh in commercial
# 4                        we need dying to spell muddying
# ...                                                  ...
# 53679  lung cancer help make the invisible disease vi...
# 53680  can mushrooms help the immune system fight can...
# 53681  for real holy i don t understand how so many p...
# 53682                      they paid   million uberfacts
# 53683  choreography mashup ll achahakyeon choreograph...
#
#                            url                                 tags  \
# 0      https://t.co/FpAstfF67l                                   []
# 1      https://t.co/pw6xYLUph5                                   []
# 2      https://t.co/XYsPhTkcDX                                   []
# 3      https://t.co/yyadIxV48k                                   []
# 4      https://t.co/WJxZL1TkfM                                   []
# ...                        ...                                  ...
# 53679  https://t.co/IB1idH6a9B                                   []
# 53680  https://t.co/9uQR8dN1cA                                   []
# 53681                      NaN  ['@davidhelman_', '@CowboysNation']
# 53682                      NaN                       ['@UberFacts']
# 53683  https://t.co/ZfG2oqGCGy                                   []
#
#                                 hashtags
# 0                                     []
# 1                                     []
# 2                                     []
# 3                                     []
# 4                                     []
# ...                                  ...
# 53679           [WorldCancerDay, health]
# 53680           [WorldCancerDay, health]
# 53681                                 []
# 53682                        [uberfacts]
# 53683  [achahakyeon, ChoreographyMashup]
#
# [53684 rows x 9 columns]

# %%
tweets['account_type'].describe()
bot_tweets = tweets.loc[tweets['account_type'] == 'bot']
human_tweets = tweets.loc[tweets['account_type'] == 'human']
bot_tweets_text = bot_tweets["text"]
human_tweets_text = human_tweets["text"]
bot_tweets_text
# Out:
# 0              we can t extract the avenge from scavengers
# 1                 we can t get the other out of geothermal
# 2                      you can t spell panoply without ply
# 3                              put the myrrh in commercial
# 4                          we need dying to spell muddying
#                                ...
# 53676    i liked a video restored republic via a gcr up...
# 53677    lungleavin day how we turned something tragic ...
# 53678    no early link between all metal hip implants a...
# 53679    lung cancer help make the invisible disease vi...
# 53680    can mushrooms help the immune system fight can...
# Name: text, Length: 10772, dtype: object

# %%
#bot tweets
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import nltk
nltk.download('all')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
lemma = WordNetLemmatizer()
bot_tweets_tokens = []
for sentence in bot_tweets_text:
    bot_tweets_tokens.append(word_tokenize(sentence))
bot_tweets_tokens_2 = []
for sentence in bot_tweets_tokens:
    sentence2 = []
    for word in sentence:
        if word not in stopwords.words('english'):
            sentence2.append(word)
    bot_tweets_tokens_2.append(sentence2)
bot_tweets_tokens_2
bot_tweets_tokens_3 = []
for sentence in bot_tweets_tokens_2:
    sentence3 = []
    for word in sentence:
        sentence3.append(lemma.lemmatize(word))
    bot_tweets_tokens_3.append(sentence3)
len(bot_tweets_tokens_3)
bot_tweets_tokens_4 = []
for sentence in bot_tweets_tokens_3:
    sentence4 = []
    for word in sentence:
        sentence4.append(PorterStemmer().stem(word))
    bot_tweets_tokens_4.append(sentence4)

# %%
human_tweets_tokens = []
for sentence in human_tweets_text:
    human_tweets_tokens.append(word_tokenize(sentence))
human_tweets_tokens_2 = []
for sentence in human_tweets_tokens:
    sentence2 = []
    for word in sentence:
        if word not in stopwords.words('english'):
            sentence2.append(word)
    human_tweets_tokens_2.append(sentence2)
human_tweets_tokens_2
human_tweets_tokens_3 = []
for sentence in human_tweets_tokens_2:
    sentence3 = []
    for word in sentence:
        sentence3.append(lemma.lemmatize(word))
    human_tweets_tokens_3.append(sentence3)
len(human_tweets_tokens_3)
human_tweets_tokens_4 = []
for sentence in human_tweets_tokens_3:
    sentence4 = []
    for word in sentence:
        sentence4.append(PorterStemmer().stem(word))
    human_tweets_tokens_4.append(sentence4)

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
#print(bot_tweets_tokens_4)
human_tweets_str = []
for i in range(len(human_tweets_tokens_4)):
    human_tweets_str.append(" ".join(human_tweets_tokens_4[i]))
vectorizer = CountVectorizer().fit(human_tweets_str)
human_tweets_tfidf = TfidfTransformer().fit_transform(vectorizer.transform(human_tweets_str))

bot_tweets_str = []
for i in range(len(bot_tweets_tokens_4)):
    bot_tweets_str.append(" ".join(bot_tweets_tokens_4[i]))
bot_tweets_tfidf = TfidfTransformer().fit_transform(vectorizer.transform(bot_tweets_str))
(human_tweets_tfidf, bot_tweets_tfidf)
# Out:
# (<42912x36795 sparse matrix of type '<class 'numpy.float64'>'
#  	with 380447 stored elements in Compressed Sparse Row format>,
#  <10772x36795 sparse matrix of type '<class 'numpy.float64'>'
#  	with 82615 stored elements in Compressed Sparse Row format>)

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
from scipy.sparse import csr_matrix
new_matrix = human_tweets_tfidf * csr_matrix.transpose(bot_tweets_tfidf)
new_matrix
import matplotlib.pyplot as plt

# plt.matshow(np.random.random(new_matrix.todense()));
# plt.colorbar()
# plt.show()
# import seaborn as sns
# sns.heatmap(new_matrix.todense(), vmin=0, vmax=0.2)
# Cosine similarity takes too long so doing dot product for now intead
###
# Actual Cosine Similarity 
# cos_similarities = []
# for row_human in human_tweets_tfidf:
#     for row_bot in bot_tweets_tfidf:
#         cos_similarities.append(cosine_similarity(row_human, row_bot))
###
import numpy as np
from matplotlib import pyplot as plt
fig, ax1 = plt.subplots(1,1)
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
im = ax1.imshow(new_matrix.todense(), cmap="copper_r", vmin=0, vmax = 0.05)
plt.colorbar(im)
plt.show()

# %%
# Dot Product between Bot and Bot Tweets
dot_prod_matrix_bots = bot_tweets_tfidf * csr_matrix.transpose(bot_tweets_tfidf)
# sns.heatmap(dot_prod_matrix_bots.todense(), vmin=0, vmax=0.2)
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
plt.title('Dot-Product between bot and bot tweets', fontdict={'fontsize': 10,
 'fontweight' : plt.rcParams['axes.titleweight'],
 'verticalalignment': 'baseline'})
plt.xlabel('Bot')
plt.ylabel('Bot') 
im = plt.imshow(dot_prod_matrix_bots.todense(), cmap="copper_r", vmin=0, vmax = 0.05)
plt.colorbar(im)
plt.show()

# %%
# Dot Product between Human and Human Tweets
dot_prod_matrix_human = human_tweets_tfidf * csr_matrix.transpose(human_tweets_tfidf)
# sns.heatmap(dot_prod_matrix_human.todense(), vmin=0, vmax=0.2)
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
im = plt.imshow(dot_prod_matrix_human.todense(), cmap="copper_r", vmin=0, vmax = 0.05)
plt.colorbar(im)
plt.show()

# %%
print("% of zero values in human-human dot product matrix:", (42912*42912 - 125714546) /(42912*42912))
print("% of zero values in bot-bot dot product matrix:", (10772*10772 - 5978611) /(10772*10772))
print("% of zero values in human-bot dot product matrix:", (42912*10772 - 26490969) /(42912*10772))
# Out:
# % of zero values in human-human dot product matrix: 0.9317302961394104
# % of zero values in bot-bot dot product matrix: 0.9484762330278511
# % of zero values in human-bot dot product matrix: 0.9426910114652205

# %%
human_tweets_str_df = pd.DataFrame(human_tweets_str)
human_tweets_str_df.to_csv('processed_human_tweets.csv')
bot_tweets_str_df = pd.DataFrame(bot_tweets_str)
bot_tweets_str_df.to_csv('processed_bot_tweets.csv')
