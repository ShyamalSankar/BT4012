# %% [markdown]
# ### Import Packages and Reading of Data

# %%
import time
import warnings
import pickle

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, LogisticRegression
from sklearn import metrics
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV, cross_val_score, RepeatedKFold
from sklearn.pipeline import make_pipeline
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.inspection import permutation_importance

pd.set_option("display.max_columns", None)
warnings.filterwarnings("ignore")

# %%
# Reading of Excel
dataset = pd.read_csv('cleaned_others_dataset.csv')
#dataset = dataset.drop(columns=["protected", "is_quoted_retweets"])

# %%
dataset
# Out:
#        verified  location  followers_count  following_count  tweet_count  \
# 0             0         0             1997                5        17090
# 1             0         1              785              829          251
# 2             0         0              243             1232         1469
# 3             0         1              749              838         2518
# 4             1         1           737048              128         4739
# ...         ...       ...              ...              ...          ...
# 33581         1         1           367523            17291        24084
# 33582         0         1               14                0          238
# 33583         0         0              395              492        21437
# 33584         0         0              159              618         3021
# 33585         1         1           803247                7         3159
#
#        isFraud  un_no_of_char  un_special_char  un_uppercase  name_no_of_char  \
# ...

# %% [markdown]
# ### Feature Engineering

# %%
x_train, x_test, y_train, y_test = train_test_split(dataset.drop(columns=["isFraud"]), dataset["isFraud"], test_size = 0.2, random_state=101)
print("Train set:", x_train.shape, y_train.shape)
print("Test set:", x_test.shape, y_test.shape)
# Out:
# Train set: (26868, 17) (26868,)
# Test set: (6718, 17) (6718,)

# %%
scaler = StandardScaler()
fitted = scaler.fit(x_train)
X_train_fitted = fitted.transform(x_train)
X_test_fitted = fitted.transform(x_test)

# %%
x_train = pd.DataFrame(X_train_fitted, columns = x_train.columns)
x_test = pd.DataFrame(X_test_fitted, columns = x_test.columns)
y_train = pd.DataFrame(y_train, columns = ["isFraud"])
y_test = pd.DataFrame(y_test, columns = ["isFraud"])

# %%
x_bin_train = x_train[["verified", 
               "location", 
               "un_special_char", 
               "un_uppercase", 
               "name_special_char", 
               "name_uppercase", 
               "des_external_links", 
               "has_description"]]
x_bin_test = x_test[["verified", 
               "location", 
               "un_special_char", 
               "un_uppercase", 
               "name_special_char", 
               "name_uppercase", 
               "des_external_links", 
               "has_description"]]
x_num_train = x_train[["followers_count", 
                 "following_count", 
                 "tweet_count", 
                 "un_no_of_char", 
                 "name_no_of_char", 
                 "des_no_of_usertags", 
                 "des_no_of_hashtags", 
                 "account_age_in_days", 
                 "average_tweets_per_day"]]
x_num_test = x_test[["followers_count", 
                 "following_count", 
                 "tweet_count", 
                 "un_no_of_char", 
                 "name_no_of_char", 
                 "des_no_of_usertags", 
                 "des_no_of_hashtags", 
                 "account_age_in_days", 
                 "average_tweets_per_day"]]

# %% [markdown]
# # Naive Bayes
# * Model (Grid Search + Randomized Search)
# * Error Metrics
# * Plot for Feature Importance

# %% [markdown]
# ### Grid Search

# %% [markdown]
# #### GaussianNB

# %%
parameters = {
    'var_smoothing': np.logspace(0,-9, num=200) 
}
    
grid_search = GridSearchCV(
    estimator=GaussianNB(),
    param_grid=parameters,
    scoring = 'f1',
    n_jobs = -1,
    cv = 5,
    verbose=True
)

# %%
# %%time

grid_search.fit(x_num_train, y_train)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# /usr/local/lib/python3.9/site-packages/sklearn/utils/validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.9/site-packages/sklearn/utils/validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.9/site-packages/sklearn/utils/validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
print(grid_search.best_estimator_)
model_gnb = grid_search.best_estimator_
y_pred = model_gnb.fit(x_num_train, y_train).predict(x_num_test)
lg_loss = metrics.log_loss(y_test, y_pred)
print(f'Log Loss: {lg_loss}')
roc_auc = metrics.roc_auc_score(y_test, y_pred)
print(f'ROC AUC: {roc_auc}')
precision = metrics.precision_score(y_test, y_pred)
print(f'Precision: {precision}')
recall = metrics.recall_score(y_test, y_pred)
print(f'Recall: {recall}')
f1_score = metrics.f1_score(y_test, y_pred)
print(f'F1-score: {f1_score}')
# Out:
# GaussianNB(var_smoothing=2.4374441501222216e-05)
# Log Loss: 11.871255219298735
# ROC AUC: 0.6317291404247927
# Precision: 0.48521400778210116
# Recall: 0.5584415584415584
# F1-score: 0.5192587965854674

# %% [markdown]
# #### BernoulliNB

# %%
parameters = {
    'alpha': [0, 1e-10, 1e-09, 1e-08, 1e-07, 1e-06, 1e-05, 1e-04, 1e-03, 1e-02, 1e-01]
}
    
grid_search = GridSearchCV(
    estimator=BernoulliNB(),
    param_grid=parameters,
    scoring = 'f1',
    n_jobs = -1,
    cv = 5,
    verbose=True
)

# %%
# %%time

grid_search.fit(x_bin_train, y_train)
# Out:
# Fitting 5 folds for each of 11 candidates, totalling 55 fits
# /usr/local/lib/python3.9/site-packages/sklearn/utils/validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.9/site-packages/sklearn/utils/validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.9/site-packages/sklearn/naive_bayes.py:591: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/naive_bayes.py:591: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   warnings.warn(
# ...

# %%
print(grid_search.best_estimator_)
model_gnb = grid_search.best_estimator_
y_pred = model_gnb.fit(x_bin_train, y_train).predict(x_bin_test)
lg_loss = metrics.log_loss(y_test, y_pred)
print(f'Log Loss: {lg_loss}')
roc_auc = metrics.roc_auc_score(y_test, y_pred)
print(f'ROC AUC: {roc_auc}')
precision = metrics.precision_score(y_test, y_pred)
print(f'Precision: {precision}')
recall = metrics.recall_score(y_test, y_pred)
print(f'Recall: {recall}')
f1_score = metrics.f1_score(y_test, y_pred)
print(f'F1-score: {f1_score}')
# Out:
# BernoulliNB(alpha=0)
# Log Loss: 8.683608259279419
# ROC AUC: 0.6902798850325088
# Precision: 0.6543700340522134
# Recall: 0.516345723242275
# F1-score: 0.5772215269086358

# %% [markdown]
# ### Randomized Search

# %% [markdown]
# #### GaussianNB

# %%
parameters = {
    'var_smoothing': np.logspace(0,-9, num=200) 
}
    
random_search = RandomizedSearchCV(
    estimator=GaussianNB(),
    param_distributions=parameters,
    scoring = 'f1',
    n_jobs=-1,
    cv=5,
    verbose=10,
    n_iter=50,
    random_state=123
)

# %%
# %%time

random_search.fit(x_num_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# /usr/local/lib/python3.9/site-packages/sklearn/utils/validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.9/site-packages/sklearn/utils/validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.9/site-packages/sklearn/utils/validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
print(random_search.best_estimator_)
model_gnb = random_search.best_estimator_
y_pred = model_gnb.fit(x_num_train, y_train).predict(x_num_test)
lg_loss = metrics.log_loss(y_test, y_pred)
print(f'Log Loss: {lg_loss}')
roc_auc = metrics.roc_auc_score(y_test, y_pred)
print(f'ROC AUC: {roc_auc}')
precision = metrics.precision_score(y_test, y_pred)
print(f'Precision: {precision}')
recall = metrics.recall_score(y_test, y_pred)
print(f'Recall: {recall}')
f1_score = metrics.f1_score(y_test, y_pred)
print(f'F1-score: {f1_score}')
# Out:
# GaussianNB(var_smoothing=1.8041864093920718e-06)
# Log Loss: 11.871255219298735
# ROC AUC: 0.6317291404247927
# Precision: 0.48521400778210116
# Recall: 0.5584415584415584
# F1-score: 0.5192587965854674

# %% [markdown]
# #### BernoulliNB

# %%
parameters = {
    'alpha': [0, 1e-10, 1e-09, 1e-08, 1e-07, 1e-06, 1e-05, 1e-04, 1e-03, 1e-02, 1e-01]
}
    
random_search = RandomizedSearchCV(
    estimator=BernoulliNB(),
    param_distributions=parameters,
    scoring = 'f1',
    n_jobs=-1,
    cv=5,
    verbose=10,
    n_iter=50,
    random_state=123
)

# %%
# %%time

random_search.fit(x_bin_train, y_train)
# Out:
# Fitting 5 folds for each of 11 candidates, totalling 55 fits
# /usr/local/lib/python3.9/site-packages/sklearn/utils/validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.9/site-packages/sklearn/utils/validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.9/site-packages/sklearn/naive_bayes.py:591: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/naive_bayes.py:591: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   warnings.warn(
# ...

# %%
print(random_search.best_estimator_)
model_gnb = random_search.best_estimator_
y_pred = model_gnb.fit(x_bin_train, y_train).predict(x_bin_test)
lg_loss = metrics.log_loss(y_test, y_pred)
print(f'Log Loss: {lg_loss}')
roc_auc = metrics.roc_auc_score(y_test, y_pred)
print(f'ROC AUC: {roc_auc}')
precision = metrics.precision_score(y_test, y_pred)
print(f'Precision: {precision}')
recall = metrics.recall_score(y_test, y_pred)
print(f'Recall: {recall}')
f1_score = metrics.f1_score(y_test, y_pred)
print(f'F1-score: {f1_score}')
# Out:
# BernoulliNB(alpha=0)
# Log Loss: 8.683608259279419
# ROC AUC: 0.6902798850325088
# Precision: 0.6543700340522134
# Recall: 0.516345723242275
# F1-score: 0.5772215269086358

# %% [markdown]
# ### Feature Importance
# https://stackoverflow.com/questions/62933365/how-to-get-the-feature-importance-in-gaussian-naive-bayes

# %%
optim_model_num = GaussianNB(var_smoothing=0.07401959996915641)
optim_model_num.fit(x_num_train, y_train)
imps = permutation_importance(optim_model_num, x_num_test, y_test)
feature = pd.DataFrame(imps.importances_mean, x_num_train.columns.T, columns=['Feature Importance']).sort_values(by='Feature Importance', ascending=False)
feature
# Out:
#                         Feature Importance
# account_age_in_days               0.038732
# des_no_of_hashtags                0.011879
# average_tweets_per_day            0.008872
# tweet_count                       0.006460
# followers_count                   0.005716
# des_no_of_usertags                0.004674
# name_no_of_char                   0.004585
# following_count                  -0.000179
# un_no_of_char                    -0.000566

# %%
optim_model_bin = BernoulliNB(alpha=0)
optim_model_bin.fit(x_bin_train, y_train)
#print(optim_model_bin.class_log_prior_)
imps = permutation_importance(optim_model_bin, x_bin_test, y_test)
feature = pd.DataFrame(imps.importances_mean, x_bin_train.columns.T, columns=['Feature Importance']).sort_values(by='Feature Importance', ascending=False)
feature
# Out:
#                     Feature Importance
# has_description               0.067371
# location                      0.032123
# des_external_links            0.031646
# verified                      0.031617
# name_uppercase                0.004406
# name_special_char             0.000685
# un_special_char               0.000000
# un_uppercase                 -0.000595
