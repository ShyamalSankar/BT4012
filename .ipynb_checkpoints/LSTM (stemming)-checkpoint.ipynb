# %%
import pandas as pd
import numpy as np
import nltk
import re
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM, Conv1D, MaxPool1D, BatchNormalization
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score



#We are going to use word vectorization to embed the words
import gensim

# %%
bot_tweets = pd.read_csv('processed_bot_tweets.csv')

# %%
human_tweets = pd.read_csv('processed_human_tweets.csv')

# %%
dbot_tweets['']
# Out:
#    Unnamed: 0                          0
# 0           0      extract aveng scaveng
# 1           1               get geotherm
# 2           2  spell panopli without pli
# 3           3         put myrrh commerci
# 4           4       need die spell muddi

# %% [markdown]
# # Preprocessing the tweets
# Here, we shall do things like change common short hands into full form (in order to deal with the issue of punctuation removal)

# %%
#First, we convert words like can't, won't etc into cannot and will not
short_form_dict = {
"ain't": "is not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he'll've": "he he will have",
"he's": "he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how is",
"I'd": "I would",
"I'd've": "I would have",
"I'll": "I will",
"I'll've": "I will have",
"I'm": "I am",
"I've": "I have",
"i'd": "i would",
"i'd've": "i would have",
"i'll": "i will",
"i'll've": "i will have",
"i'm": "i am",
"i've": "i have",
"isn't": "is not",
"it'd": "it would",
"it'd've": "it would have",
"it'll": "it will",
"it'll've": "it will have",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she would",
"she'd've": "she would have",
"she'll": "she will",
"she'll've": "she will have",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so as",
"that'd": "that would",
"that'd've": "that would have",
"that's": "that is",
"there'd": "there would",
"there'd've": "there would have",
"there's": "there is",
"they'd": "they would",
"they'd've": "they would have",
"they'll": "they will",
"they'll've": "they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what'll've": "what will have",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"when's": "when is",
"when've": "when have",
"where'd": "where did",
"where's": "where is",
"where've": "where have",
"who'll": "who will",
"who'll've": "who will have",
"who's": "who is",
"who've": "who have",
"why's": "why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you would",
"you'd've": "you would have",
"you'll": "you will",
"you'll've": "you will have",
"you're": "you are",
"you've": "you have",}

# %%
tweets.head()
# Out:
#              id                                     uncleaned_text  \
# 0  7.874060e+17  We can't extract the\n"Avenge" from\n"Scavenge...
# 1  7.874060e+17  We can't get the\n"Other" out of\n"Geothermal"...
# 2  7.874060e+17  You can't spell\n"Panoply"\nwithout "Ply" http...
# 3  7.874060e+17  Put the "Myrrh"\nin "Commercial" https://t.co/...
# 4  7.874060e+17  We need "Dying"\nto spell "Muddying" https://t...
#
#   account_type emoji emoji_text                                         text  \
# 0          bot    {}         []  we can t extract the avenge from scavengers
# 1          bot    {}         []     we can t get the other out of geothermal
# 2          bot    {}         []          you can t spell panoply without ply
# 3          bot    {}         []                  put the myrrh in commercial
# 4          bot    {}         []              we need dying to spell muddying
#
#                        url tags
# 0  https://t.co/FpAstfF67l   []
# 1  https://t.co/pw6xYLUph5   []
# 2  https://t.co/XYsPhTkcDX   []
# 3  https://t.co/yyadIxV48k   []
# 4  https://t.co/WJxZL1TkfM   []

# %%
#Things to keep: Capitalisation of words, punctuation, emojis and their positions

# %%
#Preprocessing steps (ie cleaning of text and including important information like emojis)

# %% [markdown]
# # Train test split, model training and word embedding

# %%
#create the X and y classes
tweets['isBot'] = 0
tweets.loc[tweets['account_type'] == 'bot', 'isBot'] = 1
y = tweets.isBot
X = tweets[['text']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
#first, just embed the cleaned tweets and see the results

#store the cleaned tweets in a list of lists representing the split
X_train_sentence = [d.split() for d in X_train.text.tolist()]

# %%
#create the word to vector
#try a 100 dimensional vector first
dim = 100
#Fit a Word2Vec model on our dataset
w2v = gensim.models.Word2Vec(sentences = X_train_sentence, vector_size = dim, window = 10, min_count = 1)

# %%
w2v.wv.most_similar('bad')
# Out:
# [('exactly', 0.9558676481246948),
#  ('funny', 0.948704719543457),
#  ('ok', 0.9470049738883972),
#  ('yeah', 0.9424236416816711),
#  ('pretty', 0.9381675720214844),
#  ('boring', 0.9365601539611816),
#  ('okay', 0.9332564473152161),
#  ('sad', 0.9298112988471985),
#  ('crazy', 0.9292920231819153),
#  ('actually', 0.9290502071380615)]

# %%
len(w2v.wv.key_to_index)
# Out:
# 50623

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train_sentence)

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'to': 2,
#  'a': 3,
#  'i': 4,
#  'and': 5,
#  'you': 6,
#  'of': 7,
#  'in': 8,
#  'for': 9,
#  'is': 10,
#  'it': 11,
#  's': 12,
#  'this': 13,
#  'on': 14,
#  'my': 15,
#  'that': 16,
#  'with': 17,
#  't': 18,
#  'be': 19,
#  'your': 20,
#  'at': 21,
#  'we': 22,
#  'are': 23,
#  'me': 24,
#  'have': 25,
#  'so': 26,
#  'all': 27,
#  'was': 28,
#  'just': 29,
#  'not': 30,
#  'can': 31,
#  'but': 32,
#  'from': 33,
#  'out': 34,
#  'what': 35,
#  'by': 36,
#  'one': 37,
#  'they': 38,
#  'm': 39,
#  'our': 40,
#  'as': 41,
#  'more': 42,
#  'up': 43,
#  'get': 44,
#  'if': 45,
#  'about': 46,
#  'like': 47,
#  'do': 48,
#  'new': 49,
#  'now': 50,
#  'will': 51,
#  'he': 52,
#  'love': 53,
#  'an': 54,
#  'how': 55,
#  'time': 56,
#  'when': 57,
#  'who': 58,
#  'or': 59,
#  'there': 60,
#  'no': 61,
#  'day': 62,
#  'here': 63,
#  'has': 64,
#  'thank': 65,
#  'don': 66,
#  'today': 67,
#  're': 68,
#  'people': 69,
#  'see': 70,
#  'good': 71,
#  'been': 72,
#  'know': 73,
#  'us': 74,
#  'their': 75,
#  'great': 76,
#  'back': 77,
#  'his': 78,
#  'some': 79,
#  'would': 80,
#  'go': 81,
#  've': 82,
#  'her': 83,
#  'happy': 84,
#  'she': 85,
#  '2': 86,
#  'had': 87,
#  'them': 88,
#  'make': 89,
#  'only': 90,
#  'much': 91,
#  'need': 92,
#  '1': 93,
#  'thanks': 94,
#  'got': 95,
#  'best': 96,
#  'first': 97,
#  'right': 98,
#  'still': 99,
#  'way': 100,
#  'over': 101,
#  'year': 102,
#  'work': 103,
#  'why': 104,
#  'life': 105,
#  '3': 106,
#  'want': 107,
#  'these': 108,
#  'think': 109,
#  'please': 110,
#  'check': 111,
#  'll': 112,
#  'too': 113,
#  'going': 114,
#  'week': 115,
#  'last': 116,
#  'am': 117,
#  'years': 118,
#  'help': 119,
#  'should': 120,
#  'via': 121,
#  'show': 122,
#  'always': 123,
#  'really': 124,
#  'did': 125,
#  'after': 126,
#  'let': 127,
#  'very': 128,
#  'than': 129,
#  'off': 130,
#  'never': 131,
#  'were': 132,
#  'game': 133,
#  'even': 134,
#  'into': 135,
#  'because': 136,
#  'being': 137,
#  'could': 138,
#  'him': 139,
#  'take': 140,
#  '5': 141,
#  'look': 142,
#  'world': 143,
#  'come': 144,
#  'person': 145,
#  'also': 146,
#  'well': 147,
#  'any': 148,
#  'live': 149,
#  'then': 150,
#  'many': 151,
#  'photo': 152,
#  'next': 153,
#  'every': 154,
#  'where': 155,
#  'd': 156,
#  'most': 157,
#  'everyone': 158,
#  'night': 159,
#  'watch': 160,
#  'family': 161,
#  'other': 162,
#  'down': 163,
#  'say': 164,
#  'home': 165,
#  'two': 166,
#  '10': 167,
#  'man': 168,
#  'team': 169,
#  'free': 170,
#  'better': 171,
#  'win': 172,
#  'hope': 173,
#  'twitter': 174,
#  'amazing': 175,
#  '4': 176,
#  'find': 177,
#  'ever': 178,
#  'made': 179,
#  'may': 180,
#  'those': 181,
#  'tonight': 182,
#  'again': 183,
#  'join': 184,
#  'big': 185,
#  'keep': 186,
#  'support': 187,
#  'fun': 188,
#  'same': 189,
#  'since': 190,
#  'feel': 191,
#  'before': 192,
#  'friends': 193,
#  'u': 194,
#  'someone': 195,
#  'which': 196,
#  'posted': 197,
#  'video': 198,
#  'things': 199,
#  'lol': 200,
#  'its': 201,
#  'season': 202,
#  'getting': 203,
#  'wait': 204,
#  'something': 205,
#  'said': 206,
#  'read': 207,
#  'days': 208,
#  'thing': 209,
#  'use': 210,
#  'play': 211,
#  'birthday': 212,
#  'yes': 213,
#  'another': 214,
#  'long': 215,
#  'sure': 216,
#  '2022': 217,
#  'looking': 218,
#  'through': 219,
#  'coming': 220,
#  'news': 221,
#  'old': 222,
#  'doing': 223,
#  'checked': 224,
#  'stop': 225,
#  'does': 226,
#  'while': 227,
#  'didn': 228,
#  '6': 229,
#  'money': 230,
#  'part': 231,
#  'real': 232,
#  'around': 233,
#  'automatically': 234,
#  'book': 235,
#  'little': 236,
#  'give': 237,
#  '7': 238,
#  'own': 239,
#  'tomorrow': 240,
#  'miss': 241,
#  'favorite': 242,
#  'music': 243,
#  'october': 244,
#  'such': 245,
#  'away': 246,
#  'hey': 247,
#  'lot': 248,
#  'excited': 249,
#  'y': 250,
#  'beautiful': 251,
#  'learn': 252,
#  'share': 253,
#  'watching': 254,
#  'link': 255,
#  'bad': 256,
#  'anyone': 257,
#  'start': 258,
#  'morning': 259,
#  'put': 260,
#  'full': 261,
#  'school': 262,
#  'tell': 263,
#  '8': 264,
#  'both': 265,
#  'proud': 266,
#  'done': 267,
#  'hard': 268,
#  'call': 269,
#  'god': 270,
#  'ready': 271,
#  'weekend': 272,
#  'doesn': 273,
#  'story': 274,
#  'women': 275,
#  'found': 276,
#  'few': 277,
#  'having': 278,
#  'guys': 279,
#  'change': 280,
#  'yet': 281,
#  'everything': 282,
#  'month': 283,
#  'oh': 284,
#  'shit': 285,
#  'working': 286,
#  'friday': 287,
#  'already': 288,
#  'end': 289,
#  'without': 290,
#  'trying': 291,
#  'actually': 292,
#  'episode': 293,
#  'top': 294,
#  'available': 295,
#  'thought': 296,
#  'follow': 297,
#  'making': 298,
#  'might': 299,
#  'special': 300,
#  'house': 301,
#  'nothing': 302,
#  'business': 303,
#  'soon': 304,
#  'city': 305,
#  'vote': 306,
#  'trump': 307,
#  'believe': 308,
#  'must': 309,
#  'followed': 310,
#  'care': 311,
#  'kids': 312,
#  'hear': 313,
#  'tickets': 314,
#  'open': 315,
#  'friend': 316,
#  'finally': 317,
#  'talk': 318,
#  'together': 319,
#  'w': 320,
#  'art': 321,
#  'high': 322,
#  'won': 323,
#  'health': 324,
#  'congratulations': 325,
#  'sorry': 326,
#  'account': 327,
#  'movie': 328,
#  'times': 329,
#  'service': 330,
#  'during': 331,
#  'place': 332,
#  'anything': 333,
#  'maybe': 334,
#  'remember': 335,
#  'media': 336,
#  'ago': 337,
#  'country': 338,
#  'point': 339,
#  'says': 340,
#  '9': 341,
#  'looks': 342,
#  'state': 343,
#  'black': 344,
#  'stay': 345,
#  'job': 346,
#  'until': 347,
#  'left': 348,
#  'name': 349,
#  'gonna': 350,
#  '30': 351,
#  'try': 352,
#  'loved': 353,
#  'baby': 354,
#  'heart': 355,
#  'needs': 356,
#  'sign': 357,
#  'latest': 358,
#  'hi': 359,
#  'song': 360,
#  'seen': 361,
#  'party': 362,
#  'true': 363,
#  'online': 364,
#  'used': 365,
#  'against': 366,
#  'listen': 367,
#  'head': 368,
#  'each': 369,
#  'white': 370,
#  'forward': 371,
#  'nice': 372,
#  'isn': 373,
#  'makes': 374,
#  'event': 375,
#  'cool': 376,
#  'awesome': 377,
#  'post': 378,
#  'community': 379,
#  'lost': 380,
#  'enough': 381,
#  'wrong': 382,
#  'food': 383,
#  'president': 384,
#  'run': 385,
#  'wish': 386,
#  'enjoy': 387,
#  'tweet': 388,
#  'future': 389,
#  'wow': 390,
#  'chance': 391,
#  'fuck': 392,
#  'fall': 393,
#  'went': 394,
#  '0': 395,
#  'power': 396,
#  'whole': 397,
#  'far': 398,
#  'guy': 399,
#  '100': 400,
#  'able': 401,
#  'social': 402,
#  'bring': 403,
#  'series': 404,
#  'set': 405,
#  'using': 406,
#  'experience': 407,
#  'mean': 408,
#  'app': 409,
#  'yeah': 410,
#  'girl': 411,
#  'children': 412,
#  'once': 413,
#  'yourself': 414,
#  'hours': 415,
#  'saying': 416,
#  'took': 417,
#  '11': 418,
#  'visit': 419,
#  'moment': 420,
#  'pretty': 421,
#  'taking': 422,
#  'under': 423,
#  'congrats': 424,
#  '12': 425,
#  'bio': 426,
#  'important': 427,
#  'company': 428,
#  'meet': 429,
#  'order': 430,
#  'thinking': 431,
#  'face': 432,
#  '20': 433,
#  'different': 434,
#  'saw': 435,
#  'rest': 436,
#  'football': 437,
#  'early': 438,
#  'past': 439,
#  'kind': 440,
#  'else': 441,
#  'least': 442,
#  'super': 443,
#  'games': 444,
#  'unfollowed': 445,
#  'fans': 446,
#  'x': 447,
#  'mind': 448,
#  'haven': 449,
#  'list': 450,
#  'late': 451,
#  '15': 452,
#  'playing': 453,
#  'covid': 454,
#  'water': 455,
#  'though': 456,
#  'buy': 457,
#  'podcast': 458,
#  'came': 459,
#  'weeks': 460,
#  'absolutely': 461,
#  'called': 462,
#  'red': 463,
#  'local': 464,
#  'giving': 465,
#  'hello': 466,
#  'words': 467,
#  'history': 468,
#  'car': 469,
#  'public': 470,
#  'incredible': 471,
#  'office': 472,
#  'national': 473,
#  'waiting': 474,
#  'saturday': 475,
#  'matter': 476,
#  'second': 477,
#  'others': 478,
#  'men': 479,
#  'myself': 480,
#  'fucking': 481,
#  'hate': 482,
#  'phone': 483,
#  'pay': 484,
#  'woman': 485,
#  'hit': 486,
#  'mom': 487,
#  'number': 488,
#  'send': 489,
#  'less': 490,
#  'students': 491,
#  'probably': 492,
#  'ass': 493,
#  'gets': 494,
#  'grateful': 495,
#  'hot': 496,
#  'america': 497,
#  'level': 498,
#  'ok': 499,
#  'biden': 500,
#  'space': 501,
#  'peace': 502,
#  'sale': 503,
#  'fan': 504,
#  'seeing': 505,
#  'crazy': 506,
#  'talking': 507,
#  'definitely': 508,
#  'three': 509,
#  'between': 510,
#  'sunday': 511,
#  'young': 512,
#  'welcome': 513,
#  'safe': 514,
#  'summer': 515,
#  'shows': 516,
#  'glad': 517,
#  'daily': 518,
#  'wanted': 519,
#  'human': 520,
#  'easy': 521,
#  'b': 522,
#  'heard': 523,
#  'months': 524,
#  'line': 525,
#  'wasn': 526,
#  'told': 527,
#  'single': 528,
#  'california': 529,
#  'started': 530,
#  'ask': 531,
#  'tour': 532,
#  'almost': 533,
#  'save': 534,
#  'forget': 535,
#  'perfect': 536,
#  'lives': 537,
#  'goes': 538,
#  'yesterday': 539,
#  'update': 540,
#  'issue': 541,
#  'close': 542,
#  'fight': 543,
#  'course': 544,
#  'feeling': 545,
#  'living': 546,
#  'idea': 547,
#  'possible': 548,
#  'cannot': 549,
#  'wants': 550,
#  'behind': 551,
#  'police': 552,
#  'park': 553,
#  'project': 554,
#  'n': 555,
#  'guess': 556,
#  'american': 557,
#  'war': 558,
#  'move': 559,
#  'halloween': 560,
#  'area': 561,
#  'film': 562,
#  '24': 563,
#  'small': 564,
#  'cause': 565,
#  'e': 566,
#  'class': 567,
#  'instead': 568,
#  'exactly': 569,
#  'damn': 570,
#  'bit': 571,
#  'comes': 572,
#  'stuff': 573,
#  'star': 574,
#  'boy': 575,
#  '000': 576,
#  'market': 577,
#  'problem': 578,
#  'click': 579,
#  'side': 580,
#  'dm': 581,
#  'action': 582,
#  '19': 583,
#  '22': 584,
#  'light': 585,
#  'hell': 586,
#  'truly': 587,
#  'half': 588,
#  'case': 589,
#  'york': 590,
#  'books': 591,
#  'official': 592,
#  'group': 593,
#  'ones': 594,
#  'along': 595,
#  'photos': 596,
#  'sharing': 597,
#  'dog': 598,
#  'self': 599,
#  'tv': 600,
#  'report': 601,
#  'album': 602,
#  'room': 603,
#  'oct': 604,
#  'september': 605,
#  'sad': 606,
#  'literally': 607,
#  'celebrate': 608,
#  'wonderful': 609,
#  'ad': 610,
#  'worth': 611,
#  'brother': 612,
#  'question': 613,
#  'c': 614,
#  'website': 615,
#  'below': 616,
#  'fire': 617,
#  'body': 618,
#  'hold': 619,
#  'running': 620,
#  '50': 621,
#  'break': 622,
#  'happen': 623,
#  'pick': 624,
#  'details': 625,
#  'page': 626,
#  'florida': 627,
#  'happened': 628,
#  'million': 629,
#  'rights': 630,
#  'added': 631,
#  'agree': 632,
#  'christmas': 633,
#  'means': 634,
#  'needed': 635,
#  'luck': 636,
#  'hour': 637,
#  'youtube': 638,
#  'store': 639,
#  'im': 640,
#  'road': 641,
#  'blue': 642,
#  'understand': 643,
#  'collection': 644,
#  'forever': 645,
#  'access': 646,
#  'drop': 647,
#  'across': 648,
#  'brand': 649,
#  'worst': 650,
#  'release': 651,
#  'become': 652,
#  'enter': 653,
#  'pre': 654,
#  'continue': 655,
#  'email': 656,
#  'county': 657,
#  'plan': 658,
#  'final': 659,
#  'data': 660,
#  '14': 661,
#  'energy': 662,
#  'entire': 663,
#  'opportunity': 664,
#  'turn': 665,
#  'sometimes': 666,
#  'minutes': 667,
#  'girls': 668,
#  'system': 669,
#  'word': 670,
#  'appreciate': 671,
#  'following': 672,
#  'interested': 673,
#  'later': 674,
#  'hair': 675,
#  'step': 676,
#  'law': 677,
#  'shop': 678,
#  'sending': 679,
#  'court': 680,
#  'huge': 681,
#  'starting': 682,
#  'ya': 683,
#  'dead': 684,
#  'shot': 685,
#  'missed': 686,
#  'gotta': 687,
#  'giveaway': 688,
#  'reading': 689,
#  'deal': 690,
#  'customer': 691,
#  'code': 692,
#  'sent': 693,
#  'couldn': 694,
#  'fantastic': 695,
#  'p': 696,
#  'funny': 697,
#  'message': 698,
#  'dear': 699,
#  'f': 700,
#  'fact': 701,
#  'short': 702,
#  'pm': 703,
#  'wanna': 704,
#  'leave': 705,
#  'child': 706,
#  'article': 707,
#  'son': 708,
#  'journey': 709,
#  'air': 710,
#  'fast': 711,
#  'dad': 712,
#  'eat': 713,
#  'vs': 714,
#  'especially': 715,
#  'center': 716,
#  'career': 717,
#  'strong': 718,
#  'asked': 719,
#  '18': 720,
#  'date': 721,
#  'reason': 722,
#  'bro': 723,
#  '21': 724,
#  'act': 725,
#  'thursday': 726,
#  'newprofilepic': 727,
#  'piece': 728,
#  'dream': 729,
#  'trip': 730,
#  'ukraine': 731,
#  'queen': 732,
#  'omg': 733,
#  'including': 734,
#  'meeting': 735,
#  'west': 736,
#  'anniversary': 737,
#  'rock': 738,
#  'r': 739,
#  'gone': 740,
#  'questions': 741,
#  'cover': 742,
#  'due': 743,
#  'stream': 744,
#  'price': 745,
#  'watched': 746,
#  'often': 747,
#  'states': 748,
#  'works': 749,
#  'mine': 750,
#  'walk': 751,
#  'november': 752,
#  'tried': 753,
#  'create': 754,
#  'paid': 755,
#  'fashion': 756,
#  'building': 757,
#  '1st': 758,
#  'london': 759,
#  'loss': 760,
#  'hand': 761,
#  'outside': 762,
#  'death': 763,
#  'either': 764,
#  'loving': 765,
#  'monday': 766,
#  'seems': 767,
#  'stories': 768,
#  'weather': 769,
#  '99': 770,
#  'street': 771,
#  'instagram': 772,
#  'honor': 773,
#  'government': 774,
#  'calling': 775,
#  'content': 776,
#  'info': 777,
#  'current': 778,
#  'aren': 779,
#  'mother': 780,
#  'race': 781,
#  'learning': 782,
#  'cancer': 783,
#  'inside': 784,
#  'campaign': 785,
#  'o': 786,
#  'sounds': 787,
#  'john': 788,
#  'performance': 789,
#  '13': 790,
#  'followers': 791,
#  'alone': 792,
#  '25': 793,
#  'mental': 794,
#  'truth': 795,
#  'front': 796,
#  'club': 797,
#  'texas': 798,
#  'voice': 799,
#  'workers': 800,
#  'thoughts': 801,
#  'yours': 802,
#  'election': 803,
#  'student': 804,
#  'wear': 805,
#  'green': 806,
#  'based': 807,
#  'response': 808,
#  'issues': 809,
#  'contact': 810,
#  'register': 811,
#  'happening': 812,
#  'nyc': 813,
#  'wearing': 814,
#  'sweet': 815,
#  'okay': 816,
#  'mr': 817,
#  '2020': 818,
#  'taken': 819,
#  'near': 820,
#  'pass': 821,
#  'fine': 822,
#  'answer': 823,
#  'north': 824,
#  'style': 825,
#  'gave': 826,
#  'gift': 827,
#  'jobs': 828,
#  'videos': 829,
#  'record': 830,
#  'add': 831,
#  'site': 832,
#  'beyond': 833,
#  'choose': 834,
#  'card': 835,
#  'lovely': 836,
#  'picture': 837,
#  'beach': 838,
#  'cute': 839,
#  'couple': 840,
#  'interview': 841,
#  '16': 842,
#  'ways': 843,
#  'dude': 844,
#  'low': 845,
#  'return': 846,
#  'played': 847,
#  'information': 848,
#  'beat': 849,
#  'kid': 850,
#  'wouldn': 851,
#  'ahead': 852,
#  'review': 853,
#  'apple': 854,
#  'sound': 855,
#  'plus': 856,
#  '00': 857,
#  'lots': 858,
#  'college': 859,
#  'united': 860,
#  'stand': 861,
#  'interesting': 862,
#  'process': 863,
#  'families': 864,
#  'takes': 865,
#  'coffee': 866,
#  'boys': 867,
#  'longer': 868,
#  'cut': 869,
#  'box': 870,
#  'personal': 871,
#  'writing': 872,
#  'members': 873,
#  'knew': 874,
#  'feels': 875,
#  'whatever': 876,
#  'celebrating': 877,
#  'success': 878,
#  'view': 879,
#  'king': 880,
#  '2023': 881,
#  'ain': 882,
#  'russia': 883,
#  'ticket': 884,
#  'catch': 885,
#  'moving': 886,
#  'program': 887,
#  'drive': 888,
#  'design': 889,
#  'sense': 890,
#  'middle': 891,
#  'wishing': 892,
#  'test': 893,
#  'ban': 894,
#  '2018': 895,
#  'choice': 896,
#  'cat': 897,
#  'stupid': 898,
#  'gives': 899,
#  'eyes': 900,
#  'smile': 901,
#  'speak': 902,
#  'chat': 903,
#  'opening': 904,
#  'imagine': 905,
#  'league': 906,
#  'snail': 907,
#  'dr': 908,
#  'sick': 909,
#  'artist': 910,
#  'education': 911,
#  'jesus': 912,
#  '17': 913,
#  'wife': 914,
#  'brain': 915,
#  'brought': 916,
#  'lead': 917,
#  'parents': 918,
#  'age': 919,
#  'marketing': 920,
#  'felt': 921,
#  'training': 922,
#  'leaders': 923,
#  'south': 924,
#  'deep': 925,
#  'wild': 926,
#  'joy': 927,
#  'players': 928,
#  'version': 929,
#  'happens': 930,
#  'listening': 931,
#  'build': 932,
#  'changed': 933,
#  'holiday': 934,
#  'points': 935,
#  'joined': 936,
#  'four': 937,
#  'rip': 938,
#  'worked': 939,
#  'biggest': 940,
#  'winning': 941,
#  'sleep': 942,
#  'bought': 943,
#  'la': 944,
#  'streaming': 945,
#  'san': 946,
#  'nfl': 947,
#  'tho': 948,
#  'currently': 949,
#  'quick': 950,
#  'hands': 951,
#  'goal': 952,
#  'lose': 953,
#  'leadership': 954,
#  'write': 955,
#  'tweets': 956,
#  'fix': 957,
#  'policy': 958,
#  'rt': 959,
#  'gold': 960,
#  'simple': 961,
#  'folks': 962,
#  'deserve': 963,
#  'com': 964,
#  'sir': 965,
#  'industry': 966,
#  'transponder': 967,
#  'winter': 968,
#  'clear': 969,
#  'stage': 970,
#  'etc': 971,
#  'dance': 972,
#  'killed': 973,
#  'putting': 974,
#  'board': 975,
#  'events': 976,
#  'quite': 977,
#  'wonder': 978,
#  'security': 979,
#  'brilliant': 980,
#  'present': 981,
#  'abortion': 982,
#  'bet': 983,
#  'india': 984,
#  'healthy': 985,
#  'apply': 986,
#  'gas': 987,
#  'trecru': 988,
#  'seriously': 989,
#  'supporting': 990,
#  'member': 991,
#  'five': 992,
#  'travel': 993,
#  'forgot': 994,
#  'asking': 995,
#  'screen': 996,
#  'trust': 997,
#  'grow': 998,
#  'sea': 999,
#  'ball': 1000,
#  ...}

# %%
#tokenize the words (this is for padding later)
X_train_tokens = tokenizer.texts_to_sequences(X_train_sentence)

# %%
#Since twitter only allows 280 characters, we shall keep the max length to
#the greater of 100 or whatever maximum length is found in the dataset
max_length = max(100, max(len(x) for x in X_train_tokens))

# %%
#Next, we can pad the sequences
X_train_tokens = pad_sequences(X_train_tokens, maxlen = max_length)

# %%
X_train_tokens.shape
# Out:
# (42947, 100)

# %%
vocabulary_size = len(tokenizer.word_index) + 1
vocab = tokenizer.word_index

# %%
#create the embedding matrix according to our word embeddings
embedding_mat = np.zeros((vocabulary_size, dim))
num_words = 0
#insert the word embeddings into our initialised object
for word, token in tokenizer.word_index.items():

    #get the corresponding vector to the word and the token
    #if the word is present in the dictionary, then we append the corresponding matrix else we continue
    if word in w2v.wv:
        vector = w2v.wv[word]
        embedding_mat[token] = vector
        num_words +=1

# %%
print(num_words, vocabulary_size)
# Out:
# 50623 50624

# %%
w2v.wv['i']
# Out:
# array([-3.13183737e+00,  1.97719920e+00,  1.11884749e+00,  7.85967588e-01,
#         1.55958235e+00, -2.28807354e+00,  3.01679087e+00,  3.43878675e+00,
#         1.79740310e+00, -2.20963979e+00,  2.14060521e+00, -6.08246982e-01,
#         1.72386396e+00, -1.08845639e+00,  8.06091011e-01, -1.88506818e+00,
#         1.49513328e+00, -8.17900956e-01,  3.19327533e-01,  5.82843006e-01,
#         9.12853420e-01, -2.57807493e+00,  3.09868526e+00,  6.70830965e-01,
#        -1.61713588e+00,  1.45080400e+00,  9.34126675e-01,  1.74601357e-02,
#        -8.58879611e-02, -2.52781153e-01,  9.29399729e-01,  5.74091673e-01,
#         8.02235901e-01,  3.72274041e-01,  4.46549475e-01,  1.28073502e+00,
#         2.31775117e+00, -8.17898035e-01,  4.51606996e-02,  1.00636482e+00,
#         4.56896633e-01, -1.08267760e+00, -1.17508575e-01,  1.52134740e+00,
#         2.23008886e-01,  6.34794310e-02,  9.33153555e-02, -1.28938949e+00,
#        -1.01465559e+00, -3.29777151e-01,  2.62829256e+00, -1.86563492e+00,
#         1.19415998e-01, -1.26384771e+00, -9.09515023e-01,  3.21624940e-03,
#         1.58853889e+00,  2.43348742e+00, -2.91297227e-01, -2.06695169e-01,
#         2.06616640e+00,  8.33110809e-01,  4.39951229e+00, -3.31430852e-01,
#        -1.13962209e+00, -9.55118537e-01,  8.38249981e-01,  2.73450756e+00,
#        -1.49560797e+00,  4.97832485e-02,  1.63500226e+00, -2.64793664e-01,
#         1.65216982e+00,  2.57546616e+00,  1.42069626e+00, -9.82324302e-01,
#        -3.91650975e-01,  4.75005209e-01, -6.28616631e-01,  7.71456838e-01,
#        -5.98335624e-01,  1.67617798e+00,  1.54843915e+00, -2.46356539e-02,
#        -1.08352041e+00, -1.59740555e+00,  4.49538279e+00,  2.79542732e+00,
#         2.11832666e+00, -2.52314478e-01,  1.39371586e+00,  1.70849419e+00,
#         1.19627345e+00, -3.64823967e-01,  3.54713082e+00,  2.17671013e+00,
#         3.85801464e-01, -3.70886493e+00, -1.48900688e+00, -2.80962372e+00],
#       dtype=float32)

# %%
#Since the dataset is an imbalanced dataset, we shall assign higher weights for the bot examples
#the weights assigned to the classes shall be a reciprocal of the frequencies
class_weights = {0:1.334,1:3.992}

# %%
#creating the neural network, starting with a relatively simple architechture
model = Sequential()
#create the embedding layer for the conversion of inputs to embedded vectors
model.add(Embedding(vocabulary_size, output_dim = dim, weights = [embedding_mat], input_length = max_length, trainable = False))
#All these LSTMS run for a 100 "timesteps" as determined by the max length parameter the units is the determine the outputsize
model.add(LSTM(units = 256, recurrent_dropout=0.3))
model.add(Dense(1, activation = 'sigmoid'))
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['acc'])

# %%
model.fit(X_train_tokens, y_train,  epochs = 8, class_weight = class_weights)
# Out:
# Epoch 1/8
# 1343/1343 [==============================] - 4191s 3s/step - loss: 1.2744 - acc: 0.6852
# Epoch 2/8
# 1343/1343 [==============================] - 2044s 2s/step - loss: 1.2355 - acc: 0.7037
# Epoch 3/8
# 1343/1343 [==============================] - 937s 697ms/step - loss: 1.2086 - acc: 0.7140
# Epoch 4/8
# 1343/1343 [==============================] - 1129s 841ms/step - loss: 1.1940 - acc: 0.7232
# Epoch 5/8
# 1343/1343 [==============================] - 808s 601ms/step - loss: 1.1798 - acc: 0.7257
# Epoch 6/8
# 1343/1343 [==============================] - 822s 612ms/step - loss: 1.1662 - acc: 0.7316
# Epoch 7/8
# 1343/1343 [==============================] - 863s 643ms/step - loss: 1.1533 - acc: 0.7305
# Epoch 8/8
# 1343/1343 [==============================] - 795s 592ms/step - loss: 1.1327 - acc: 0.7437

# %%
#applying the preprocessing steps on the test set and seeing the performance
X_test_sentence = [d.split() for d in X_test.text.tolist()]
X_test_tokens = tokenizer.texts_to_sequences(X_test_sentence)

# %%
X_test_tokens = pad_sequences(X_test_tokens, maxlen = max_length)

# %%
y_pred = np.where(model.predict(X_test_tokens) > 0.5, 1,0)
# Out:
# 336/336 [==============================] - 25s 75ms/step

# %%
y_pred = y_pred.reshape((y_pred.shape[0],))

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.74      0.79      8598
#            1       0.33      0.52      0.40      2139
#
#     accuracy                           0.69     10737
#    macro avg       0.59      0.63      0.60     10737
# weighted avg       0.75      0.69      0.72     10737

# %%
y_pred_train = model.predict(X_train_tokens)
# Out:
# 1343/1343 [==============================] - 137s 102ms/step

# %%
y_pred_train = np.where(y_pred_train > 0.5, 1,0)
y_pred_train = y_pred_train.reshape((y_pred_train.shape[0],))

# %%
print(classification_report(y_train, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.87     34314
#            1       0.50      0.57      0.53      8633
#
#     accuracy                           0.80     42947
#    macro avg       0.69      0.71      0.70     42947
# weighted avg       0.81      0.80      0.80     42947
